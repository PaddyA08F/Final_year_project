# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.profiler import profile, record_function, ProfilerActivity
from numpy import log 

torch.manual_seed(123)

# %%
# Generalisable NN
torch.manual_seed(32)

class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed):
        super().__init__()

        # Define size of input and output layers
        self.input_dim = input_dim
        self.output_dim = output_dim

        # Define size of hidden layers (number of neurons)
        self.layer_dim = layer_dim

        # Define how many hidden layers
        self.num_hidden = num_hidden

        # Define activation function of neurons 
        self.activation = nn.Tanh()

        # Define regularisation parameter
        self.reg_param = reg_param

        # Defin regularisation exponent power
        self.reg_power = reg_power

        # Define random seed to be used
        self.ran_seed = ran_seed

        # Build architectyre
        self.input_layer = nn.Linear(self.input_dim, self.layer_dim)
        self.hidden_layers = nn.ModuleList([nn.Linear(self.layer_dim, self.layer_dim) for _ in range(num_hidden-1)])
        self.output_layer = nn.Linear(self.layer_dim, self.output_dim)
        self.layers = nn.ModuleList([self.input_layer, *self.hidden_layers, self.output_layer])

        # Initialise weights
        self.initialise()

    def forward(self, x):
    # Function defines the forward pass of the network
        for _, f in enumerate(self.layers[:-1]):
            x = self.activation(f(x))
        x = self.output_layer(x)
        return x
        
    def initialise(self):
    # Function defines initilaising the unfrozen weights of the network using Xavier (Glorot) initialisiation
        torch.manual_seed(self.ran_seed)
        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                #torch.nn.init.xavier_uniform_(m.weight, gain=g)
                torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)

    def regularization(self):
    # Function defines regularisation
        reg_loss = 0
        for name, param in self.named_parameters():
            if 'weight' in name:
                reg_loss = reg_loss + torch.norm(param, self.reg_power)
        return self.reg_param * reg_loss

# %%
# Define the PINN class
class PINN(nn.Module):
    def __init__(self, balancing_parameter, input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed):
        super(PINN, self).__init__()

        # Initialize the NeuralNetwork for intensity and absorption coefficient
        self.intensity_network = NeuralNetwork(input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed)
        self.emission_network = NeuralNetwork(input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed)

        self.balancing_parameter = balancing_parameter


    def compute_pde_residual(self, input_distance):
            '''
            Enforces PDE via automatic differentiation.
            Uses NN to predict intensity and absorption, and calculates dI/ds.
            '''
            input_distance.requires_grad = True

            # Predict intensity and absorption coefficient
            pred_intensity = self.intensity_network(input_distance)
            emission = self.emission_network(input_distance) # using distance as emission does not depend on intensity 

            # Compute derivative dI/ds using autograd
            dintensity = torch.autograd.grad(pred_intensity.sum(), input_distance, create_graph=True)[0]

            # PDE residual: dI/ds - j = 0
            residual = dintensity - emission

            return residual.reshape(-1,)
    
    def compute_loss(self, dist_bound, int_bound, input_distance, input_intensity, input_emission, verbose=True):
        '''
        Computes loss using boundary conditions, physics residuals, and data loss.
        '''
        # Predict intensity at boundaries
        pred_boundary_intensity = self.intensity_network(dist_bound)
       

        # Compute PDE residuals (physics enforcement)
        physics_residual = self.compute_pde_residual(input_distance)

        # **Hard enforce boundary conditions**
        boundary_loss = torch.mean((pred_boundary_intensity - int_bound)**2)

        # Compute data residuals inside of the slab
        pred_intensity = self.intensity_network(input_distance)
        data_residual = input_intensity - pred_intensity

        # Compute loss terms (L2 loss)
        physics_loss = torch.mean(abs(physics_residual)**2)
        data_loss = torch.mean(abs(data_residual)**2)

        # Add regularization terms
        intensity_reg = self.intensity_network.regularization()
        emission_reg = self.emission_network.regularization()
    
        # Total loss (weighted combination)
        total_loss = torch.log(self.balancing_parameter * (boundary_loss) + physics_loss + intensity_reg + emission_reg)
        
        if verbose:
            print(f"Total Loss: {total_loss.item():.4f} | PDE Loss: {torch.log10(physics_loss).item():.4f} | "
                f"Boundary Loss: {torch.log10(boundary_loss).item():.4f} | Data Loss: {torch.log10(data_loss).item():.4f}")
        
        return total_loss
        

# Define the function for the analytical solution
def analytical_solution(input_distance, emission_value, I0=0.0):
    return I0 + emission_value*input_distance

def plot_results(model, input_distance, analytical_solution, emission_value):
    # Predict intensity from the trained model
    pred_intensity = model.intensity_network(input_distance).detach()

    # Compute the analytical solution using the true emission value
    anal_intensity = analytical_solution(input_distance, emission_value)

    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(input_distance.detach().numpy(), pred_intensity.detach().numpy(), label='Predicted Intensity', color='b')
    plt.plot(input_distance.detach().numpy(), anal_intensity.detach().numpy(), label='Analytical Intensity', color='r', linestyle='--')
    plt.xlabel('Distance (s)')
    plt.ylabel('Intensity')
    plt.legend()
    plt.title('Intensity Prediction vs Analytical Solution')
    plt.show()

    pred_emission = model.emission_network(input_distance).detach().numpy().flatten()

    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(input_distance.detach().numpy(), pred_emission, label='Predicted emission', color='b')
    plt.axhline(y=emission_value, color='r', linestyle='--', label=f'True emission ({emission_value})')
    plt.xlabel('Distance (s)')
    plt.ylabel('emission (j)')
    plt.legend()
    plt.title('Predicted vs Analytical emission')
    plt.show()

def fit(model, optimizer, dist_bound, int_bound, input_distance, input_intensity,input_emission, epochs):
    '''
    Fits the PINN model using Adam optimization.
    '''
    history = []  # Store loss values

    for epoch in range(epochs):
        def closure():
            optimizer.zero_grad()
            loss = model.compute_loss(dist_bound, int_bound, input_distance, input_intensity, input_emission)
            loss.backward()
            history.append(loss.item())  # Store loss at each epoch
            return loss

        optimizer.step(closure)

        if epoch % 10 == 0:
            print(f"Epoch {epoch}, Loss: {history[-1]:.6f}")

    print(f"Final Loss: {history[-1]:.6f}")

def calculate_relative_l2_error(model, input_distance, analytical_solution, emission_value):
    """
    Calculates the relative L2 error between the predicted intensity and the analytical solution as a percentage.
    """
    # Predict intensity from the trained model
    pred_intensity = model.intensity_network(input_distance).detach().flatten()

    # Compute the analytical solution using the true alpha value
    anal_intensity = analytical_solution(input_distance, emission_value).flatten()

    # Compute the L2 norm of the difference between predicted and analytical solutions
    numerator = torch.norm(pred_intensity - anal_intensity, p=2)

    # Compute the L2 norm of the analytical solution
    denominator = torch.norm(anal_intensity, p=2)

    # Compute the relative L2 error as a percentage
    relative_l2_error = (numerator / denominator) * 100

    return relative_l2_error.item()

# ==== Initialize Model and Training ==== 
#adjustable parameters
balancing_parameter = 5.0  
input_dim = 1
output_dim = 1
layer_dim = 20
num_hidden = 6
reg_param = 0.001
reg_power = 1
ran_seed = 32

model = PINN(balancing_parameter, input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed)

#define Adam optimizer
optimizer_Adam = optim.Adam(
    list(model.intensity_network.parameters()) + list(model.emission_network.parameters()),
    lr=1e-3,  # Adam optimizer typically uses learning rates like this
    betas=(0.5, 0.999),  # Lower momentum for better convergence
    eps=1e-8,  # Small value to prevent division by zero
    weight_decay=0  # LBFGS doesn't typically use weight decay, so keep it 0
)

# Define LBFGS optimizer
optimizer_LBFGS = optim.LBFGS(
    list(model.intensity_network.parameters()) + list(model.emission_network.parameters()),
    lr=1e-3,
    max_iter=1000,
    max_eval=50000,
    history_size=150,
    line_search_fn="strong_wolfe",
    tolerance_change=np.finfo(float).eps
)

# ==== Training Data ==== 
I0 = 0.0  # Initial intensity
emission_value = 2.0  # Absorption coefficient

dist_bound = torch.tensor([[0.0], [10.0]])  # Slab distance from 0 to 10
int_bound = torch.tensor([[I0], [I0 + emission_value*10]])  # Intensity at boundaries
x_min = dist_bound.min().item()
x_max = dist_bound.max().item()
input_distance = torch.linspace(x_min, x_max, 100).view(-1, 1)  # Interior grid

input_intensity = analytical_solution(input_distance, emission_value)

# Train the model
fit(model, optimizer_LBFGS, dist_bound, int_bound, input_distance, input_intensity, emission_value, epochs=20)

# Calculate relative L2 error as a percentage
relative_l2_error = calculate_relative_l2_error(model, input_distance, analytical_solution, emission_value)
print(f"Relative L2 Error: {relative_l2_error:.6f}%")

# Plot the results **only once** after training
plot_results(model, input_distance, analytical_solution,emission_value)
# Out:
# Total Loss: 6.8729 | PDE Loss: -0.7806 | Boundary Loss: 2.2853 | Data Loss: 2.1091
# Total Loss: 6.8729 | PDE Loss: -0.7805 | Boundary Loss: 2.2853 | Data Loss: 2.1090
# Total Loss: 6.8727 | PDE Loss: -0.7800 | Boundary Loss: 2.2852 | Data Loss: 2.1089
# Total Loss: 6.8714 | PDE Loss: -0.7762 | Boundary Loss: 2.2846 | Data Loss: 2.1082
# Total Loss: 6.8647 | PDE Loss: -0.7559 | Boundary Loss: 2.2817 | Data Loss: 2.1044
# Total Loss: 6.7908 | PDE Loss: -0.4958 | Boundary Loss: 2.2495 | Data Loss: 2.0597
# Total Loss: 6.7210 | PDE Loss: -0.1593 | Boundary Loss: 2.2189 | Data Loss: 2.0096
# Total Loss: 6.7208 | PDE Loss: -0.1582 | Boundary Loss: 2.2188 | Data Loss: 2.0094
# Total Loss: 6.7195 | PDE Loss: -0.1532 | Boundary Loss: 2.2183 | Data Loss: 2.0086
# Total Loss: 6.7067 | PDE Loss: -0.0991 | Boundary Loss: 2.2127 | Data Loss: 1.9999
# Total Loss: 6.6161 | PDE Loss: 0.3181 | Boundary Loss: 2.1724 | Data Loss: 1.9384
# Total Loss: 6.6159 | PDE Loss: 0.3192 | Boundary Loss: 2.1723 | Data Loss: 1.9383
# Total Loss: 6.6137 | PDE Loss: 0.3290 | Boundary Loss: 2.1714 | Data Loss: 1.9367
# Total Loss: 6.6033 | PDE Loss: 0.3767 | Boundary Loss: 2.1667 | Data Loss: 1.9292
# Total Loss: 6.5488 | PDE Loss: 0.6064 | Boundary Loss: 2.1419 | Data Loss: 1.8909
# Total Loss: 6.5478 | PDE Loss: 0.6103 | Boundary Loss: 2.1414 | Data Loss: 1.8902
# Total Loss: 6.5431 | PDE Loss: 0.6279 | Boundary Loss: 2.1393 | Data Loss: 1.8871
# Total Loss: 6.5177 | PDE Loss: 0.7179 | Boundary Loss: 2.1275 | Data Loss: 1.8701
# Total Loss: 6.3834 | PDE Loss: 1.0706 | Boundary Loss: 2.0637 | Data Loss: 1.7808
# Total Loss: 6.1727 | PDE Loss: 1.8167 | Boundary Loss: 1.9167 | Data Loss: 1.5313
# Total Loss: 6.1721 | PDE Loss: 1.8168 | Boundary Loss: 1.9164 | Data Loss: 1.5311
# Total Loss: 6.1696 | PDE Loss: 1.8175 | Boundary Loss: 1.9150 | Data Loss: 1.5303
# Total Loss: 6.1390 | PDE Loss: 1.8234 | Boundary Loss: 1.8985 | Data Loss: 1.5224
# Total Loss: 5.7023 | PDE Loss: 1.8058 | Boundary Loss: 1.6710 | Data Loss: 1.4881
# Total Loss: 5.5158 | PDE Loss: 1.6164 | Boundary Loss: 1.6150 | Data Loss: 1.5308
# Total Loss: 5.5147 | PDE Loss: 1.6163 | Boundary Loss: 1.6144 | Data Loss: 1.5313
# Total Loss: 5.5048 | PDE Loss: 1.6149 | Boundary Loss: 1.6095 | Data Loss: 1.5361
# Total Loss: 5.4282 | PDE Loss: 1.6030 | Boundary Loss: 1.5715 | Data Loss: 1.5954
# Total Loss: 5.4272 | PDE Loss: 1.6034 | Boundary Loss: 1.5709 | Data Loss: 1.5958
# Total Loss: 5.4184 | PDE Loss: 1.6070 | Boundary Loss: 1.5655 | Data Loss: 1.5990
# Total Loss: 5.3296 | PDE Loss: 1.6408 | Boundary Loss: 1.5089 | Data Loss: 1.6335
# Total Loss: 4.6341 | PDE Loss: 1.8619 | Boundary Loss: 0.7627 | Data Loss: 2.0083
# Total Loss: 4.6325 | PDE Loss: 1.8617 | Boundary Loss: 0.7607 | Data Loss: 2.0087
# Total Loss: 4.6181 | PDE Loss: 1.8597 | Boundary Loss: 0.7431 | Data Loss: 2.0122
# Total Loss: 4.4933 | PDE Loss: 1.8431 | Boundary Loss: 0.5685 | Data Loss: 2.0454
# Total Loss: 4.4917 | PDE Loss: 1.8424 | Boundary Loss: 0.5675 | Data Loss: 2.0454
# Total Loss: 4.4842 | PDE Loss: 1.8394 | Boundary Loss: 0.5629 | Data Loss: 2.0457
# Total Loss: 4.3995 | PDE Loss: 1.8057 | Boundary Loss: 0.5120 | Data Loss: 2.0483
# Total Loss: 3.9272 | PDE Loss: 1.6031 | Boundary Loss: 0.2754 | Data Loss: 2.0370
# Total Loss: 7.3027 | PDE Loss: 0.1236 | Boundary Loss: 2.4718 | Data Loss: 2.3820
# Total Loss: 3.3042 | PDE Loss: 1.3105 | Boundary Loss: 0.0449 | Data Loss: 1.9418
# Total Loss: 2.5981 | PDE Loss: 0.9700 | Boundary Loss: -0.2419 | Data Loss: 1.6983
# Total Loss: 2.6990 | PDE Loss: 0.6634 | Boundary Loss: 0.2560 | Data Loss: 1.2643
# Total Loss: 2.4452 | PDE Loss: 0.8257 | Boundary Loss: -0.1430 | Data Loss: 1.5299
# Total Loss: 2.4436 | PDE Loss: 0.8240 | Boundary Loss: -0.1420 | Data Loss: 1.5277
# Total Loss: 2.4368 | PDE Loss: 0.8162 | Boundary Loss: -0.1372 | Data Loss: 1.5175
# Total Loss: 2.4341 | PDE Loss: 0.8156 | Boundary Loss: -0.1399 | Data Loss: 1.5168
# Total Loss: 2.4098 | PDE Loss: 0.8102 | Boundary Loss: -0.1637 | Data Loss: 1.5106
# Total Loss: 2.1863 | PDE Loss: 0.7620 | Boundary Loss: -0.4252 | Data Loss: 1.4431
# Total Loss: 2.1842 | PDE Loss: 0.7615 | Boundary Loss: -0.4278 | Data Loss: 1.4423
# Total Loss: 2.1656 | PDE Loss: 0.7564 | Boundary Loss: -0.4511 | Data Loss: 1.4357
# Total Loss: 1.9928 | PDE Loss: 0.7091 | Boundary Loss: -0.7104 | Data Loss: 1.3625
# Total Loss: 1.9915 | PDE Loss: 0.7087 | Boundary Loss: -0.7123 | Data Loss: 1.3618
# Total Loss: 1.9792 | PDE Loss: 0.7044 | Boundary Loss: -0.7301 | Data Loss: 1.3557
# Total Loss: 1.8629 | PDE Loss: 0.6625 | Boundary Loss: -0.9200 | Data Loss: 1.2897
# Total Loss: 1.8615 | PDE Loss: 0.6619 | Boundary Loss: -0.9222 | Data Loss: 1.2888
# Total Loss: 1.8483 | PDE Loss: 0.6564 | Boundary Loss: -0.9419 | Data Loss: 1.2810
# Total Loss: 1.7842 | PDE Loss: 0.6292 | Boundary Loss: -1.0431 | Data Loss: 1.2399
# Total Loss: 1.3811 | PDE Loss: 0.3480 | Boundary Loss: -0.9973 | Data Loss: 0.5153
# Total Loss: 1.3802 | PDE Loss: 0.3479 | Boundary Loss: -1.0001 | Data Loss: 0.5155
# Total Loss: 1.3762 | PDE Loss: 0.3476 | Boundary Loss: -1.0127 | Data Loss: 0.5164
# Total Loss: 1.3551 | PDE Loss: 0.3458 | Boundary Loss: -1.0837 | Data Loss: 0.5217
# Total Loss: 1.3545 | PDE Loss: 0.3456 | Boundary Loss: -1.0849 | Data Loss: 0.5213
# Total Loss: 1.3489 | PDE Loss: 0.3434 | Boundary Loss: -1.0960 | Data Loss: 0.5183
# Total Loss: 1.2959 | PDE Loss: 0.3213 | Boundary Loss: -1.2070 | Data Loss: 0.4888
# Total Loss: 1.2951 | PDE Loss: 0.3210 | Boundary Loss: -1.2090 | Data Loss: 0.4886
# Total Loss: 1.2885 | PDE Loss: 0.3186 | Boundary Loss: -1.2267 | Data Loss: 0.4874
# Total Loss: 1.2256 | PDE Loss: 0.2942 | Boundary Loss: -1.4227 | Data Loss: 0.4747
# Total Loss: 0.9457 | PDE Loss: 0.1007 | Boundary Loss: -1.9043 | Data Loss: 0.3565
# Total Loss: 0.9449 | PDE Loss: 0.1001 | Boundary Loss: -1.9075 | Data Loss: 0.3556
# Total Loss: 0.9373 | PDE Loss: 0.0947 | Boundary Loss: -1.9377 | Data Loss: 0.3470
# Total Loss: 0.8698 | PDE Loss: 0.0447 | Boundary Loss: -2.2930 | Data Loss: 0.2787
# Total Loss: 0.8694 | PDE Loss: 0.0444 | Boundary Loss: -2.2931 | Data Loss: 0.2784
# Total Loss: 0.8659 | PDE Loss: 0.0410 | Boundary Loss: -2.2943 | Data Loss: 0.2753
# Total Loss: 0.8489 | PDE Loss: 0.0246 | Boundary Loss: -2.2867 | Data Loss: 0.2613
# Total Loss: 0.8038 | PDE Loss: -0.0530 | Boundary Loss: -1.7249 | Data Loss: 0.2253
# Total Loss: 0.8037 | PDE Loss: -0.0531 | Boundary Loss: -1.7255 | Data Loss: 0.2252
# Total Loss: 0.8034 | PDE Loss: -0.0533 | Boundary Loss: -1.7265 | Data Loss: 0.2251
# Total Loss: 0.8018 | PDE Loss: -0.0543 | Boundary Loss: -1.7332 | Data Loss: 0.2243
# Total Loss: 0.7932 | PDE Loss: -0.0600 | Boundary Loss: -1.7714 | Data Loss: 0.2197
# Total Loss: 0.7153 | PDE Loss: -0.1171 | Boundary Loss: -2.2983 | Data Loss: 0.1641
# Total Loss: 0.7150 | PDE Loss: -0.1174 | Boundary Loss: -2.2986 | Data Loss: 0.1636
# Total Loss: 0.7138 | PDE Loss: -0.1187 | Boundary Loss: -2.2997 | Data Loss: 0.1614
# Total Loss: 0.7010 | PDE Loss: -0.1337 | Boundary Loss: -2.3082 | Data Loss: 0.1364
# Total Loss: 0.6278 | PDE Loss: -0.2433 | Boundary Loss: -2.0677 | Data Loss: -0.1051
# Total Loss: 0.6277 | PDE Loss: -0.2434 | Boundary Loss: -2.0690 | Data Loss: -0.1053
# Total Loss: 0.6273 | PDE Loss: -0.2435 | Boundary Loss: -2.0736 | Data Loss: -0.1061
# Total Loss: 0.6238 | PDE Loss: -0.2454 | Boundary Loss: -2.1205 | Data Loss: -0.1138
# Total Loss: 0.6035 | PDE Loss: -0.2578 | Boundary Loss: -2.5233 | Data Loss: -0.1925
# Total Loss: 0.6035 | PDE Loss: -0.2578 | Boundary Loss: -2.5240 | Data Loss: -0.1925
# Total Loss: 0.6033 | PDE Loss: -0.2580 | Boundary Loss: -2.5270 | Data Loss: -0.1925
# Total Loss: 0.6026 | PDE Loss: -0.2587 | Boundary Loss: -2.5436 | Data Loss: -0.1921
# Total Loss: 0.5985 | PDE Loss: -0.2623 | Boundary Loss: -2.6398 | Data Loss: -0.1889
# Total Loss: 0.5985 | PDE Loss: -0.2624 | Boundary Loss: -2.6403 | Data Loss: -0.1888
# Total Loss: 0.5982 | PDE Loss: -0.2627 | Boundary Loss: -2.6427 | Data Loss: -0.1885
# Total Loss: 0.5954 | PDE Loss: -0.2662 | Boundary Loss: -2.6696 | Data Loss: -0.1851
# Total Loss: 0.5829 | PDE Loss: -0.2825 | Boundary Loss: -2.7926 | Data Loss: -0.1588
# Total Loss: 0.5827 | PDE Loss: -0.2827 | Boundary Loss: -2.7943 | Data Loss: -0.1588
# Total Loss: 0.5820 | PDE Loss: -0.2837 | Boundary Loss: -2.8025 | Data Loss: -0.1587
# Total Loss: 0.5744 | PDE Loss: -0.2938 | Boundary Loss: -2.8946 | Data Loss: -0.1572
# Total Loss: 0.5397 | PDE Loss: -0.3447 | Boundary Loss: -3.4076 | Data Loss: -0.1454
# Total Loss: 0.5394 | PDE Loss: -0.3452 | Boundary Loss: -3.4076 | Data Loss: -0.1453
# Total Loss: 0.5369 | PDE Loss: -0.3495 | Boundary Loss: -3.4062 | Data Loss: -0.1445
# Total Loss: 0.5244 | PDE Loss: -0.3707 | Boundary Loss: -3.3820 | Data Loss: -0.1399
# Total Loss: 0.4399 | PDE Loss: -0.5755 | Boundary Loss: -2.3030 | Data Loss: -0.0351
# Total Loss: 0.4397 | PDE Loss: -0.5759 | Boundary Loss: -2.3050 | Data Loss: -0.0353
# Total Loss: 0.4387 | PDE Loss: -0.5774 | Boundary Loss: -2.3144 | Data Loss: -0.0362
# Total Loss: 0.4287 | PDE Loss: -0.5941 | Boundary Loss: -2.4211 | Data Loss: -0.0460
# Total Loss: 0.4286 | PDE Loss: -0.5943 | Boundary Loss: -2.4220 | Data Loss: -0.0462
# Total Loss: 0.4281 | PDE Loss: -0.5953 | Boundary Loss: -2.4259 | Data Loss: -0.0468
# Total Loss: 0.4254 | PDE Loss: -0.6009 | Boundary Loss: -2.4476 | Data Loss: -0.0502
# Total Loss: 0.3994 | PDE Loss: -0.6585 | Boundary Loss: -2.6889 | Data Loss: -0.0898
# Total Loss: 0.3993 | PDE Loss: -0.6587 | Boundary Loss: -2.6900 | Data Loss: -0.0899
# Total Loss: 0.3990 | PDE Loss: -0.6595 | Boundary Loss: -2.6949 | Data Loss: -0.0908
# Total Loss: 0.3954 | PDE Loss: -0.6678 | Boundary Loss: -2.7450 | Data Loss: -0.0992
# Total Loss: 0.3795 | PDE Loss: -0.7075 | Boundary Loss: -3.0212 | Data Loss: -0.1436
# Total Loss: 0.3794 | PDE Loss: -0.7077 | Boundary Loss: -3.0222 | Data Loss: -0.1438
# Total Loss: 0.3792 | PDE Loss: -0.7082 | Boundary Loss: -3.0245 | Data Loss: -0.1445
# Total Loss: 0.3781 | PDE Loss: -0.7114 | Boundary Loss: -3.0388 | Data Loss: -0.1486
# Total Loss: 0.3723 | PDE Loss: -0.7285 | Boundary Loss: -3.1143 | Data Loss: -0.1720
# Total Loss: 0.3722 | PDE Loss: -0.7287 | Boundary Loss: -3.1158 | Data Loss: -0.1722
# Total Loss: 0.3720 | PDE Loss: -0.7295 | Boundary Loss: -3.1216 | Data Loss: -0.1732
# Total Loss: 0.3704 | PDE Loss: -0.7339 | Boundary Loss: -3.1545 | Data Loss: -0.1789
# Total Loss: 0.3555 | PDE Loss: -0.7806 | Boundary Loss: -3.5202 | Data Loss: -0.2455
# Total Loss: 0.3554 | PDE Loss: -0.7808 | Boundary Loss: -3.5211 | Data Loss: -0.2458
# Total Loss: 0.3552 | PDE Loss: -0.7817 | Boundary Loss: -3.5249 | Data Loss: -0.2473
# Total Loss: 0.3538 | PDE Loss: -0.7865 | Boundary Loss: -3.5442 | Data Loss: -0.2555
# Total Loss: 0.3467 | PDE Loss: -0.8126 | Boundary Loss: -3.6004 | Data Loss: -0.3028
# Total Loss: 0.3466 | PDE Loss: -0.8128 | Boundary Loss: -3.6020 | Data Loss: -0.3032
# Total Loss: 0.3464 | PDE Loss: -0.8139 | Boundary Loss: -3.6094 | Data Loss: -0.3046
# Total Loss: 0.3433 | PDE Loss: -0.8250 | Boundary Loss: -3.6806 | Data Loss: -0.3203
# Total Loss: 0.3298 | PDE Loss: -0.8801 | Boundary Loss: -3.7625 | Data Loss: -0.4094
# Total Loss: 0.3298 | PDE Loss: -0.8803 | Boundary Loss: -3.7621 | Data Loss: -0.4098
# Total Loss: 0.3295 | PDE Loss: -0.8815 | Boundary Loss: -3.7612 | Data Loss: -0.4118
# Total Loss: 0.3266 | PDE Loss: -0.8948 | Boundary Loss: -3.7327 | Data Loss: -0.4346
# Total Loss: 0.3095 | PDE Loss: -1.0207 | Boundary Loss: -2.6375 | Data Loss: -0.7530
# Total Loss: 0.3095 | PDE Loss: -1.0208 | Boundary Loss: -2.6380 | Data Loss: -0.7530
# Total Loss: 0.3094 | PDE Loss: -1.0210 | Boundary Loss: -2.6403 | Data Loss: -0.7530
# Total Loss: 0.3091 | PDE Loss: -1.0218 | Boundary Loss: -2.6483 | Data Loss: -0.7527
# Total Loss: 0.3074 | PDE Loss: -1.0264 | Boundary Loss: -2.6965 | Data Loss: -0.7515
# Total Loss: 0.3005 | PDE Loss: -1.0474 | Boundary Loss: -2.9453 | Data Loss: -0.7490
# Total Loss: 0.3004 | PDE Loss: -1.0475 | Boundary Loss: -2.9459 | Data Loss: -0.7491
# Total Loss: 0.3004 | PDE Loss: -1.0478 | Boundary Loss: -2.9484 | Data Loss: -0.7494
# Total Loss: 0.3000 | PDE Loss: -1.0494 | Boundary Loss: -2.9626 | Data Loss: -0.7514
# Total Loss: 0.2962 | PDE Loss: -1.0662 | Boundary Loss: -3.1107 | Data Loss: -0.7735
# Total Loss: 0.2962 | PDE Loss: -1.0663 | Boundary Loss: -3.1115 | Data Loss: -0.7737
# Total Loss: 0.2960 | PDE Loss: -1.0669 | Boundary Loss: -3.1151 | Data Loss: -0.7747
# Total Loss: 0.2951 | PDE Loss: -1.0721 | Boundary Loss: -3.1467 | Data Loss: -0.7839
# Total Loss: 0.2866 | PDE Loss: -1.1243 | Boundary Loss: -3.3476 | Data Loss: -0.8905
# Total Loss: 0.2866 | PDE Loss: -1.1244 | Boundary Loss: -3.3499 | Data Loss: -0.8906
# Total Loss: 0.2865 | PDE Loss: -1.1249 | Boundary Loss: -3.3603 | Data Loss: -0.8911
# Total Loss: 0.2858 | PDE Loss: -1.1282 | Boundary Loss: -3.4346 | Data Loss: -0.8946
# Total Loss: 0.2826 | PDE Loss: -1.1458 | Boundary Loss: -3.9657 | Data Loss: -0.9133
# Total Loss: 0.2826 | PDE Loss: -1.1461 | Boundary Loss: -3.9638 | Data Loss: -0.9141
# Total Loss: 0.2824 | PDE Loss: -1.1476 | Boundary Loss: -3.9551 | Data Loss: -0.9179
# Total Loss: 0.2805 | PDE Loss: -1.1633 | Boundary Loss: -3.8326 | Data Loss: -0.9615
# Total Loss: 0.2805 | PDE Loss: -1.1635 | Boundary Loss: -3.8338 | Data Loss: -0.9620
# Total Loss: 0.2803 | PDE Loss: -1.1648 | Boundary Loss: -3.8405 | Data Loss: -0.9648
# Total Loss: 0.2795 | PDE Loss: -1.1712 | Boundary Loss: -3.8737 | Data Loss: -0.9800
# Total Loss: 0.2721 | PDE Loss: -1.2379 | Boundary Loss: -3.7359 | Data Loss: -1.1771
# Total Loss: 0.2721 | PDE Loss: -1.2380 | Boundary Loss: -3.7363 | Data Loss: -1.1775
# Total Loss: 0.2720 | PDE Loss: -1.2387 | Boundary Loss: -3.7391 | Data Loss: -1.1791
# Total Loss: 0.2717 | PDE Loss: -1.2418 | Boundary Loss: -3.7505 | Data Loss: -1.1867
# Total Loss: 0.2698 | PDE Loss: -1.2594 | Boundary Loss: -3.7971 | Data Loss: -1.2314
# Total Loss: 0.2698 | PDE Loss: -1.2596 | Boundary Loss: -3.7984 | Data Loss: -1.2319
# Total Loss: 0.2697 | PDE Loss: -1.2611 | Boundary Loss: -3.8072 | Data Loss: -1.2353
# Total Loss: 0.2689 | PDE Loss: -1.2687 | Boundary Loss: -3.8507 | Data Loss: -1.2529
# Total Loss: 0.2617 | PDE Loss: -1.3475 | Boundary Loss: -3.9709 | Data Loss: -1.4753
# Total Loss: 0.2617 | PDE Loss: -1.3477 | Boundary Loss: -3.9718 | Data Loss: -1.4757
# Total Loss: 0.2616 | PDE Loss: -1.3481 | Boundary Loss: -3.9736 | Data Loss: -1.4768
# Total Loss: 0.2614 | PDE Loss: -1.3506 | Boundary Loss: -3.9855 | Data Loss: -1.4833
# Total Loss: 0.2592 | PDE Loss: -1.3777 | Boundary Loss: -4.0776 | Data Loss: -1.5571
# Total Loss: 0.2592 | PDE Loss: -1.3779 | Boundary Loss: -4.0779 | Data Loss: -1.5576
# Total Loss: 0.2592 | PDE Loss: -1.3783 | Boundary Loss: -4.0782 | Data Loss: -1.5587
# Total Loss: 0.2590 | PDE Loss: -1.3805 | Boundary Loss: -4.0792 | Data Loss: -1.5652
# Total Loss: 0.2581 | PDE Loss: -1.3929 | Boundary Loss: -4.0785 | Data Loss: -1.6015
# Total Loss: 0.2532 | PDE Loss: -1.4866 | Boundary Loss: -3.3484 | Data Loss: -1.8594
# Total Loss: 0.2531 | PDE Loss: -1.4867 | Boundary Loss: -3.3513 | Data Loss: -1.8593
# Total Loss: 0.2531 | PDE Loss: -1.4872 | Boundary Loss: -3.3653 | Data Loss: -1.8593
# Total Loss: 0.2526 | PDE Loss: -1.4898 | Boundary Loss: -3.4456 | Data Loss: -1.8588
# Total Loss: 0.2510 | PDE Loss: -1.5028 | Boundary Loss: -3.9884 | Data Loss: -1.8537
# Total Loss: 0.2510 | PDE Loss: -1.5028 | Boundary Loss: -3.9890 | Data Loss: -1.8536
# Total Loss: 0.2509 | PDE Loss: -1.5029 | Boundary Loss: -3.9912 | Data Loss: -1.8534
# Total Loss: 0.2508 | PDE Loss: -1.5043 | Boundary Loss: -4.0176 | Data Loss: -1.8502
# Total Loss: 0.2501 | PDE Loss: -1.5157 | Boundary Loss: -4.2711 | Data Loss: -1.8111
# Total Loss: 0.2501 | PDE Loss: -1.5157 | Boundary Loss: -4.2713 | Data Loss: -1.8110
# Total Loss: 0.2500 | PDE Loss: -1.5158 | Boundary Loss: -4.2724 | Data Loss: -1.8109
# Total Loss: 0.2500 | PDE Loss: -1.5163 | Boundary Loss: -4.2787 | Data Loss: -1.8098
# Total Loss: 0.2498 | PDE Loss: -1.5195 | Boundary Loss: -4.3133 | Data Loss: -1.8031
# Total Loss: 0.2498 | PDE Loss: -1.5195 | Boundary Loss: -4.3137 | Data Loss: -1.8031
# Total Loss: 0.2498 | PDE Loss: -1.5197 | Boundary Loss: -4.3155 | Data Loss: -1.8029
# Total Loss: 0.2498 | PDE Loss: -1.5201 | Boundary Loss: -4.3200 | Data Loss: -1.8023
# Total Loss: 0.2496 | PDE Loss: -1.5229 | Boundary Loss: -4.3493 | Data Loss: -1.7987
# Total Loss: 0.2486 | PDE Loss: -1.5434 | Boundary Loss: -4.5228 | Data Loss: -1.7546
# Total Loss: 0.2486 | PDE Loss: -1.5434 | Boundary Loss: -4.5227 | Data Loss: -1.7546
# Total Loss: 0.2486 | PDE Loss: -1.5435 | Boundary Loss: -4.5223 | Data Loss: -1.7546
# Total Loss: 0.2485 | PDE Loss: -1.5438 | Boundary Loss: -4.5223 | Data Loss: -1.7549
# Total Loss: 0.2485 | PDE Loss: -1.5449 | Boundary Loss: -4.5205 | Data Loss: -1.7557
# Total Loss: 0.2482 | PDE Loss: -1.5517 | Boundary Loss: -4.5137 | Data Loss: -1.7612
# Total Loss: 0.2482 | PDE Loss: -1.5517 | Boundary Loss: -4.5141 | Data Loss: -1.7613
# Total Loss: 0.2482 | PDE Loss: -1.5518 | Boundary Loss: -4.5141 | Data Loss: -1.7614
# Total Loss: 0.2482 | PDE Loss: -1.5523 | Boundary Loss: -4.5155 | Data Loss: -1.7623
# Total Loss: 0.2480 | PDE Loss: -1.5552 | Boundary Loss: -4.5248 | Data Loss: -1.7673
# Total Loss: 0.2469 | PDE Loss: -1.5812 | Boundary Loss: -4.6844 | Data Loss: -1.8209
# Total Loss: 0.2469 | PDE Loss: -1.5813 | Boundary Loss: -4.6842 | Data Loss: -1.8211
# Total Loss: 0.2469 | PDE Loss: -1.5815 | Boundary Loss: -4.6861 | Data Loss: -1.8219
# Total Loss: 0.2468 | PDE Loss: -1.5825 | Boundary Loss: -4.6909 | Data Loss: -1.8247
# Total Loss: 0.2466 | PDE Loss: -1.5880 | Boundary Loss: -4.7273 | Data Loss: -1.8413
# Total Loss: 0.2452 | PDE Loss: -1.6248 | Boundary Loss: -5.5397 | Data Loss: -1.9567
# Total Loss: 0.2452 | PDE Loss: -1.6249 | Boundary Loss: -5.5389 | Data Loss: -1.9568
# Total Loss: 0.2452 | PDE Loss: -1.6250 | Boundary Loss: -5.5422 | Data Loss: -1.9573
# Total Loss: 0.2451 | PDE Loss: -1.6261 | Boundary Loss: -5.5548 | Data Loss: -1.9597
# Total Loss: 0.2450 | PDE Loss: -1.6309 | Boundary Loss: -5.6237 | Data Loss: -1.9696
# Total Loss: 0.2450 | PDE Loss: -1.6310 | Boundary Loss: -5.6268 | Data Loss: -1.9697
# Total Loss: 0.2450 | PDE Loss: -1.6311 | Boundary Loss: -5.6307 | Data Loss: -1.9699
# Total Loss: 0.2450 | PDE Loss: -1.6313 | Boundary Loss: -5.6378 | Data Loss: -1.9702
# Total Loss: 0.2449 | PDE Loss: -1.6329 | Boundary Loss: -5.6978 | Data Loss: -1.9730
# Total Loss: 0.2445 | PDE Loss: -1.6446 | Boundary Loss: -6.5036 | Data Loss: -1.9885
# Total Loss: 0.2445 | PDE Loss: -1.6446 | Boundary Loss: -6.5096 | Data Loss: -1.9885
# Total Loss: 0.2445 | PDE Loss: -1.6449 | Boundary Loss: -6.5369 | Data Loss: -1.9887
# Total Loss: 0.2444 | PDE Loss: -1.6461 | Boundary Loss: -6.6625 | Data Loss: -1.9897
# Total Loss: 0.2440 | PDE Loss: -1.6580 | Boundary Loss: -6.5583 | Data Loss: -1.9936
# Total Loss: 0.2440 | PDE Loss: -1.6581 | Boundary Loss: -6.5524 | Data Loss: -1.9936
# Total Loss: 0.2440 | PDE Loss: -1.6582 | Boundary Loss: -6.5329 | Data Loss: -1.9936
# Total Loss: 0.2440 | PDE Loss: -1.6591 | Boundary Loss: -6.4229 | Data Loss: -1.9937
# Total Loss: 0.2438 | PDE Loss: -1.6646 | Boundary Loss: -5.8571 | Data Loss: -1.9928
# Total Loss: 0.2438 | PDE Loss: -1.6646 | Boundary Loss: -5.8551 | Data Loss: -1.9928
# Total Loss: 0.2438 | PDE Loss: -1.6648 | Boundary Loss: -5.8453 | Data Loss: -1.9928
# Total Loss: 0.2438 | PDE Loss: -1.6651 | Boundary Loss: -5.8232 | Data Loss: -1.9927
# Total Loss: 0.2437 | PDE Loss: -1.6674 | Boundary Loss: -5.6846 | Data Loss: -1.9922
# Total Loss: 0.2433 | PDE Loss: -1.6857 | Boundary Loss: -4.7693 | Data Loss: -1.9683
# Total Loss: 0.2433 | PDE Loss: -1.6857 | Boundary Loss: -4.7696 | Data Loss: -1.9683
# Total Loss: 0.2432 | PDE Loss: -1.6857 | Boundary Loss: -4.7696 | Data Loss: -1.9683
# Total Loss: 0.2432 | PDE Loss: -1.6858 | Boundary Loss: -4.7685 | Data Loss: -1.9683
# Total Loss: 0.2432 | PDE Loss: -1.6861 | Boundary Loss: -4.7626 | Data Loss: -1.9684
# Total Loss: 0.2432 | PDE Loss: -1.6881 | Boundary Loss: -4.7307 | Data Loss: -1.9687
# Total Loss: 0.2430 | PDE Loss: -1.6959 | Boundary Loss: -4.5916 | Data Loss: -1.9693
# Total Loss: 0.2430 | PDE Loss: -1.6959 | Boundary Loss: -4.5907 | Data Loss: -1.9693
# Total Loss: 0.2430 | PDE Loss: -1.6961 | Boundary Loss: -4.5909 | Data Loss: -1.9695
# Total Loss: 0.2429 | PDE Loss: -1.6964 | Boundary Loss: -4.5897 | Data Loss: -1.9701
# Total Loss: 0.2429 | PDE Loss: -1.6988 | Boundary Loss: -4.5844 | Data Loss: -1.9735
# Total Loss: 0.2425 | PDE Loss: -1.7101 | Boundary Loss: -4.5487 | Data Loss: -1.9912
# Total Loss: 0.2425 | PDE Loss: -1.7101 | Boundary Loss: -4.5493 | Data Loss: -1.9913
# Total Loss: 0.2425 | PDE Loss: -1.7102 | Boundary Loss: -4.5491 | Data Loss: -1.9915
# Total Loss: 0.2425 | PDE Loss: -1.7110 | Boundary Loss: -4.5514 | Data Loss: -1.9927
# Total Loss: 0.2424 | PDE Loss: -1.7140 | Boundary Loss: -4.5596 | Data Loss: -1.9976
# Total Loss: 0.2418 | PDE Loss: -1.7305 | Boundary Loss: -4.5854 | Data Loss: -2.0264
# Total Loss: 0.2418 | PDE Loss: -1.7306 | Boundary Loss: -4.5860 | Data Loss: -2.0264
# Total Loss: 0.2418 | PDE Loss: -1.7312 | Boundary Loss: -4.5904 | Data Loss: -2.0262
# Total Loss: 0.2417 | PDE Loss: -1.7343 | Boundary Loss: -4.6098 | Data Loss: -2.0252
# Total Loss: 0.2408 | PDE Loss: -1.7603 | Boundary Loss: -4.6424 | Data Loss: -2.0152
# Total Loss: 0.2408 | PDE Loss: -1.7605 | Boundary Loss: -4.6421 | Data Loss: -2.0153
# Total Loss: 0.2408 | PDE Loss: -1.7613 | Boundary Loss: -4.6440 | Data Loss: -2.0155
# Total Loss: 0.2405 | PDE Loss: -1.7679 | Boundary Loss: -4.6531 | Data Loss: -2.0177
# Total Loss: 0.2387 | PDE Loss: -1.8299 | Boundary Loss: -4.4762 | Data Loss: -2.0407
# Total Loss: 0.2387 | PDE Loss: -1.8300 | Boundary Loss: -4.4766 | Data Loss: -2.0407
# Total Loss: 0.2387 | PDE Loss: -1.8305 | Boundary Loss: -4.4773 | Data Loss: -2.0407
# Total Loss: 0.2386 | PDE Loss: -1.8332 | Boundary Loss: -4.4828 | Data Loss: -2.0408
# Total Loss: 0.2382 | PDE Loss: -1.8479 | Boundary Loss: -4.4925 | Data Loss: -2.0414
# Total Loss: 0.2381 | PDE Loss: -1.8480 | Boundary Loss: -4.4928 | Data Loss: -2.0415
# Total Loss: 0.2381 | PDE Loss: -1.8488 | Boundary Loss: -4.4960 | Data Loss: -2.0417
# Total Loss: 0.2380 | PDE Loss: -1.8533 | Boundary Loss: -4.5092 | Data Loss: -2.0427
# Total Loss: 0.2367 | PDE Loss: -1.8994 | Boundary Loss: -4.4696 | Data Loss: -2.0596
# Total Loss: 0.2367 | PDE Loss: -1.8996 | Boundary Loss: -4.4704 | Data Loss: -2.0597
# Total Loss: 0.2367 | PDE Loss: -1.9004 | Boundary Loss: -4.4734 | Data Loss: -2.0598
# Total Loss: 0.2366 | PDE Loss: -1.9036 | Boundary Loss: -4.4828 | Data Loss: -2.0605
# Total Loss: 0.2361 | PDE Loss: -1.9225 | Boundary Loss: -4.5109 | Data Loss: -2.0658
# Total Loss: 0.2341 | PDE Loss: -2.0149 | Boundary Loss: -3.8409 | Data Loss: -2.1350
# Total Loss: 0.2341 | PDE Loss: -2.0150 | Boundary Loss: -3.8419 | Data Loss: -2.1348
# Total Loss: 0.2341 | PDE Loss: -2.0151 | Boundary Loss: -3.8425 | Data Loss: -2.1347
# Total Loss: 0.2341 | PDE Loss: -2.0160 | Boundary Loss: -3.8491 | Data Loss: -2.1334
# Total Loss: 0.2339 | PDE Loss: -2.0208 | Boundary Loss: -3.8847 | Data Loss: -2.1267
# Total Loss: 0.2327 | PDE Loss: -2.0617 | Boundary Loss: -4.1033 | Data Loss: -2.0705
# Total Loss: 0.2327 | PDE Loss: -2.0618 | Boundary Loss: -4.1034 | Data Loss: -2.0705
# Total Loss: 0.2327 | PDE Loss: -2.0624 | Boundary Loss: -4.1053 | Data Loss: -2.0704
# Total Loss: 0.2327 | PDE Loss: -2.0652 | Boundary Loss: -4.1131 | Data Loss: -2.0700
# Total Loss: 0.2323 | PDE Loss: -2.0805 | Boundary Loss: -4.1479 | Data Loss: -2.0678
# Total Loss: 0.2307 | PDE Loss: -2.1792 | Boundary Loss: -3.8600 | Data Loss: -2.0662
# Total Loss: 0.2307 | PDE Loss: -2.1793 | Boundary Loss: -3.8622 | Data Loss: -2.0660
# Total Loss: 0.2307 | PDE Loss: -2.1794 | Boundary Loss: -3.8653 | Data Loss: -2.0658
# Total Loss: 0.2307 | PDE Loss: -2.1803 | Boundary Loss: -3.8900 | Data Loss: -2.0636
# Total Loss: 0.2305 | PDE Loss: -2.1837 | Boundary Loss: -3.9959 | Data Loss: -2.0550
# Total Loss: 0.2305 | PDE Loss: -2.1838 | Boundary Loss: -3.9967 | Data Loss: -2.0552
# Total Loss: 0.2305 | PDE Loss: -2.1839 | Boundary Loss: -3.9970 | Data Loss: -2.0553
# Total Loss: 0.2305 | PDE Loss: -2.1850 | Boundary Loss: -4.0025 | Data Loss: -2.0566
# Total Loss: 0.2304 | PDE Loss: -2.1882 | Boundary Loss: -4.0165 | Data Loss: -2.0604
# Total Loss: 0.2301 | PDE Loss: -2.2069 | Boundary Loss: -4.0917 | Data Loss: -2.0847
# Total Loss: 0.2301 | PDE Loss: -2.2070 | Boundary Loss: -4.0923 | Data Loss: -2.0848
# Total Loss: 0.2300 | PDE Loss: -2.2073 | Boundary Loss: -4.0959 | Data Loss: -2.0852
# Total Loss: 0.2300 | PDE Loss: -2.2094 | Boundary Loss: -4.1158 | Data Loss: -2.0875
# Total Loss: 0.2298 | PDE Loss: -2.2199 | Boundary Loss: -4.2297 | Data Loss: -2.0999
# Total Loss: 0.2298 | PDE Loss: -2.2200 | Boundary Loss: -4.2303 | Data Loss: -2.1001
# Total Loss: 0.2298 | PDE Loss: -2.2201 | Boundary Loss: -4.2311 | Data Loss: -2.1002
# Total Loss: 0.2298 | PDE Loss: -2.2202 | Boundary Loss: -4.2324 | Data Loss: -2.1005
# Total Loss: 0.2297 | PDE Loss: -2.2211 | Boundary Loss: -4.2394 | Data Loss: -2.1020
# Total Loss: 0.2297 | PDE Loss: -2.2261 | Boundary Loss: -4.2773 | Data Loss: -2.1103
# Total Loss: 0.2292 | PDE Loss: -2.2499 | Boundary Loss: -4.4524 | Data Loss: -2.1549
# Total Loss: 0.2292 | PDE Loss: -2.2500 | Boundary Loss: -4.4533 | Data Loss: -2.1550
# Total Loss: 0.2292 | PDE Loss: -2.2502 | Boundary Loss: -4.4567 | Data Loss: -2.1554
# Total Loss: 0.2292 | PDE Loss: -2.2506 | Boundary Loss: -4.4621 | Data Loss: -2.1561
# Total Loss: 0.2291 | PDE Loss: -2.2536 | Boundary Loss: -4.5035 | Data Loss: -2.1614
# Total Loss: 0.2289 | PDE Loss: -2.2671 | Boundary Loss: -4.7089 | Data Loss: -2.1876
# Total Loss: 0.2289 | PDE Loss: -2.2672 | Boundary Loss: -4.7094 | Data Loss: -2.1877
# Total Loss: 0.2289 | PDE Loss: -2.2673 | Boundary Loss: -4.7114 | Data Loss: -2.1881
# Total Loss: 0.2288 | PDE Loss: -2.2684 | Boundary Loss: -4.7217 | Data Loss: -2.1900
# Total Loss: 0.2287 | PDE Loss: -2.2735 | Boundary Loss: -4.7738 | Data Loss: -2.2006
# Total Loss: 0.2287 | PDE Loss: -2.2735 | Boundary Loss: -4.7746 | Data Loss: -2.2007
# Total Loss: 0.2287 | PDE Loss: -2.2737 | Boundary Loss: -4.7793 | Data Loss: -2.2009
# Total Loss: 0.2287 | PDE Loss: -2.2747 | Boundary Loss: -4.8036 | Data Loss: -2.2024
# Total Loss: 0.2286 | PDE Loss: -2.2794 | Boundary Loss: -4.9421 | Data Loss: -2.2099
# Total Loss: 0.2286 | PDE Loss: -2.2795 | Boundary Loss: -4.9424 | Data Loss: -2.2100
# Total Loss: 0.2286 | PDE Loss: -2.2796 | Boundary Loss: -4.9428 | Data Loss: -2.2102
# Total Loss: 0.2286 | PDE Loss: -2.2805 | Boundary Loss: -4.9472 | Data Loss: -2.2117
# Total Loss: 0.2285 | PDE Loss: -2.2828 | Boundary Loss: -4.9537 | Data Loss: -2.2161
# Total Loss: 0.2285 | PDE Loss: -2.2829 | Boundary Loss: -4.9562 | Data Loss: -2.2162
# Total Loss: 0.2285 | PDE Loss: -2.2829 | Boundary Loss: -4.9569 | Data Loss: -2.2162
# Total Loss: 0.2285 | PDE Loss: -2.2832 | Boundary Loss: -4.9694 | Data Loss: -2.2165
# Total Loss: 0.2285 | PDE Loss: -2.2855 | Boundary Loss: -5.0818 | Data Loss: -2.2188
# Total Loss: 0.2283 | PDE Loss: -2.2928 | Boundary Loss: -5.6193 | Data Loss: -2.2259
# Total Loss: 0.2283 | PDE Loss: -2.2928 | Boundary Loss: -5.6162 | Data Loss: -2.2259
# Total Loss: 0.2283 | PDE Loss: -2.2928 | Boundary Loss: -5.6170 | Data Loss: -2.2259
# Total Loss: 0.2283 | PDE Loss: -2.2929 | Boundary Loss: -5.6146 | Data Loss: -2.2261
# Total Loss: 0.2283 | PDE Loss: -2.2929 | Boundary Loss: -5.6116 | Data Loss: -2.2261
# Total Loss: 0.2283 | PDE Loss: -2.2930 | Boundary Loss: -5.6071 | Data Loss: -2.2263
# Total Loss: 0.2283 | PDE Loss: -2.2939 | Boundary Loss: -5.5456 | Data Loss: -2.2280
# Total Loss: 0.2281 | PDE Loss: -2.2971 | Boundary Loss: -5.1658 | Data Loss: -2.2354
# Total Loss: 0.2281 | PDE Loss: -2.2971 | Boundary Loss: -5.1685 | Data Loss: -2.2354
# Total Loss: 0.2281 | PDE Loss: -2.2971 | Boundary Loss: -5.1690 | Data Loss: -2.2354
# Total Loss: 0.2281 | PDE Loss: -2.2972 | Boundary Loss: -5.1771 | Data Loss: -2.2354
# Total Loss: 0.2281 | PDE Loss: -2.2974 | Boundary Loss: -5.2254 | Data Loss: -2.2350
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5019 | Data Loss: -2.2321
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5032 | Data Loss: -2.2321
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5044 | Data Loss: -2.2320
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5033 | Data Loss: -2.2320
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5052 | Data Loss: -2.2320
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5032 | Data Loss: -2.2320
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5044 | Data Loss: -2.2320
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5044 | Data Loss: -2.2320
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.5027 | Data Loss: -2.2320
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.4966 | Data Loss: -2.2319
# Total Loss: 0.2280 | PDE Loss: -2.2981 | Boundary Loss: -5.4896 | Data Loss: -2.2318
# Total Loss: 0.2280 | PDE Loss: -2.2980 | Boundary Loss: -5.4777 | Data Loss: -2.2315
# Total Loss: 0.2280 | PDE Loss: -2.2978 | Boundary Loss: -5.4262 | Data Loss: -2.2304
# Total Loss: 0.2280 | PDE Loss: -2.2978 | Boundary Loss: -5.4256 | Data Loss: -2.2304
# Total Loss: 0.2280 | PDE Loss: -2.2978 | Boundary Loss: -5.4274 | Data Loss: -2.2303
# Total Loss: 0.2280 | PDE Loss: -2.2978 | Boundary Loss: -5.4304 | Data Loss: -2.2301
# Total Loss: 0.2280 | PDE Loss: -2.2978 | Boundary Loss: -5.4328 | Data Loss: -2.2300
# Total Loss: 0.2280 | PDE Loss: -2.2977 | Boundary Loss: -5.4687 | Data Loss: -2.2279
# Total Loss: 0.2279 | PDE Loss: -2.2941 | Boundary Loss: -5.5130 | Data Loss: -2.2152
# Total Loss: 0.2279 | PDE Loss: -2.2941 | Boundary Loss: -5.5144 | Data Loss: -2.2152
# Total Loss: 0.2279 | PDE Loss: -2.2940 | Boundary Loss: -5.5137 | Data Loss: -2.2152
# Total Loss: 0.2279 | PDE Loss: -2.2940 | Boundary Loss: -5.5149 | Data Loss: -2.2152
# Total Loss: 0.2279 | PDE Loss: -2.2940 | Boundary Loss: -5.5150 | Data Loss: -2.2152
# Total Loss: 0.2279 | PDE Loss: -2.2940 | Boundary Loss: -5.5150 | Data Loss: -2.2151
# Total Loss: 0.2279 | PDE Loss: -2.2940 | Boundary Loss: -5.5150 | Data Loss: -2.2151
# Total Loss: 0.2279 | PDE Loss: -2.2940 | Boundary Loss: -5.5199 | Data Loss: -2.2148
# Total Loss: 0.2279 | PDE Loss: -2.2937 | Boundary Loss: -5.5345 | Data Loss: -2.2133
# Total Loss: 0.2278 | PDE Loss: -2.2917 | Boundary Loss: -5.5680 | Data Loss: -2.2047
# Total Loss: 0.2278 | PDE Loss: -2.2917 | Boundary Loss: -5.5708 | Data Loss: -2.2046
# Total Loss: 0.2278 | PDE Loss: -2.2917 | Boundary Loss: -5.5723 | Data Loss: -2.2046
# Total Loss: 0.2278 | PDE Loss: -2.2917 | Boundary Loss: -5.5856 | Data Loss: -2.2041
# Total Loss: 0.2278 | PDE Loss: -2.2917 | Boundary Loss: -5.6053 | Data Loss: -2.2035
# Total Loss: 0.2277 | PDE Loss: -2.2912 | Boundary Loss: -5.7698 | Data Loss: -2.1984
# Total Loss: 0.2274 | PDE Loss: -2.2704 | Boundary Loss: -5.7711 | Data Loss: -2.1411
# Total Loss: 0.2274 | PDE Loss: -2.2704 | Boundary Loss: -5.7738 | Data Loss: -2.1411
# Total Loss: 0.2274 | PDE Loss: -2.2705 | Boundary Loss: -5.7811 | Data Loss: -2.1411
# Total Loss: 0.2274 | PDE Loss: -2.2705 | Boundary Loss: -5.7875 | Data Loss: -2.1410
# Total Loss: 0.2274 | PDE Loss: -2.2707 | Boundary Loss: -5.8630 | Data Loss: -2.1406
# Total Loss: 0.2273 | PDE Loss: -2.2716 | Boundary Loss: -6.3758 | Data Loss: -2.1384
# Total Loss: 0.2269 | PDE Loss: -2.2721 | Boundary Loss: -6.8030 | Data Loss: -2.1277
# Total Loss: 0.2269 | PDE Loss: -2.2721 | Boundary Loss: -6.8114 | Data Loss: -2.1277
# Total Loss: 0.2269 | PDE Loss: -2.2722 | Boundary Loss: -6.8396 | Data Loss: -2.1278
# Total Loss: 0.2268 | PDE Loss: -2.2729 | Boundary Loss: -7.0904 | Data Loss: -2.1282
# Total Loss: 0.2263 | PDE Loss: -2.2755 | Boundary Loss: -5.0719 | Data Loss: -2.1357
# Total Loss: 0.2263 | PDE Loss: -2.2757 | Boundary Loss: -5.0718 | Data Loss: -2.1359
# Total Loss: 0.2263 | PDE Loss: -2.2766 | Boundary Loss: -5.0708 | Data Loss: -2.1365
# Total Loss: 0.2262 | PDE Loss: -2.2817 | Boundary Loss: -5.0365 | Data Loss: -2.1399
# Total Loss: 0.2255 | PDE Loss: -2.3135 | Boundary Loss: -4.0897 | Data Loss: -2.1637
# Total Loss: 0.2255 | PDE Loss: -2.3137 | Boundary Loss: -4.0906 | Data Loss: -2.1637
# Total Loss: 0.2255 | PDE Loss: -2.3139 | Boundary Loss: -4.0912 | Data Loss: -2.1638
# Total Loss: 0.2255 | PDE Loss: -2.3154 | Boundary Loss: -4.0967 | Data Loss: -2.1642
# Total Loss: 0.2253 | PDE Loss: -2.3238 | Boundary Loss: -4.1243 | Data Loss: -2.1661
# Total Loss: 0.2243 | PDE Loss: -2.4099 | Boundary Loss: -4.0684 | Data Loss: -2.1327
# Total Loss: 0.2243 | PDE Loss: -2.4101 | Boundary Loss: -4.0699 | Data Loss: -2.1327
# Total Loss: 0.2243 | PDE Loss: -2.4105 | Boundary Loss: -4.0740 | Data Loss: -2.1325
# Total Loss: 0.2243 | PDE Loss: -2.4109 | Boundary Loss: -4.0774 | Data Loss: -2.1323
# Total Loss: 0.2243 | PDE Loss: -2.4156 | Boundary Loss: -4.1187 | Data Loss: -2.1304
# Total Loss: 0.2239 | PDE Loss: -2.4467 | Boundary Loss: -4.4347 | Data Loss: -2.1169
# Total Loss: 0.2239 | PDE Loss: -2.4470 | Boundary Loss: -4.4339 | Data Loss: -2.1169
# Total Loss: 0.2238 | PDE Loss: -2.4483 | Boundary Loss: -4.4357 | Data Loss: -2.1167
# Total Loss: 0.2238 | PDE Loss: -2.4508 | Boundary Loss: -4.4371 | Data Loss: -2.1165
# Total Loss: 0.2236 | PDE Loss: -2.4692 | Boundary Loss: -4.4336 | Data Loss: -2.1143
# Total Loss: 0.2229 | PDE Loss: -2.5692 | Boundary Loss: -4.0948 | Data Loss: -2.0957
# Total Loss: 0.2229 | PDE Loss: -2.5695 | Boundary Loss: -4.0957 | Data Loss: -2.0957
# Total Loss: 0.2229 | PDE Loss: -2.5699 | Boundary Loss: -4.0974 | Data Loss: -2.0957
# Total Loss: 0.2229 | PDE Loss: -2.5702 | Boundary Loss: -4.0982 | Data Loss: -2.0957
# Total Loss: 0.2228 | PDE Loss: -2.5746 | Boundary Loss: -4.1122 | Data Loss: -2.0957
# Total Loss: 0.2226 | PDE Loss: -2.5984 | Boundary Loss: -4.1856 | Data Loss: -2.0952
# Total Loss: 0.2226 | PDE Loss: -2.5987 | Boundary Loss: -4.1867 | Data Loss: -2.0952
# Total Loss: 0.2226 | PDE Loss: -2.5989 | Boundary Loss: -4.1873 | Data Loss: -2.0953
# Total Loss: 0.2226 | PDE Loss: -2.6013 | Boundary Loss: -4.1944 | Data Loss: -2.0960
# Total Loss: 0.2225 | PDE Loss: -2.6154 | Boundary Loss: -4.2333 | Data Loss: -2.0997
# Total Loss: 0.2218 | PDE Loss: -2.6884 | Boundary Loss: -4.3834 | Data Loss: -2.1164
# Total Loss: 0.2218 | PDE Loss: -2.6887 | Boundary Loss: -4.3842 | Data Loss: -2.1164
# Total Loss: 0.2218 | PDE Loss: -2.6890 | Boundary Loss: -4.3858 | Data Loss: -2.1164
# Total Loss: 0.2218 | PDE Loss: -2.6896 | Boundary Loss: -4.3884 | Data Loss: -2.1164
# Total Loss: 0.2218 | PDE Loss: -2.6951 | Boundary Loss: -4.4113 | Data Loss: -2.1161
# Total Loss: 0.2215 | PDE Loss: -2.7244 | Boundary Loss: -4.5301 | Data Loss: -2.1132
# Total Loss: 0.2215 | PDE Loss: -2.7248 | Boundary Loss: -4.5306 | Data Loss: -2.1132
# Total Loss: 0.2215 | PDE Loss: -2.7261 | Boundary Loss: -4.5333 | Data Loss: -2.1132
# Total Loss: 0.2214 | PDE Loss: -2.7336 | Boundary Loss: -4.5469 | Data Loss: -2.1130
# Total Loss: 0.2210 | PDE Loss: -2.7783 | Boundary Loss: -4.5945 | Data Loss: -2.1069
# Total Loss: 0.2210 | PDE Loss: -2.7785 | Boundary Loss: -4.5964 | Data Loss: -2.1067
# Total Loss: 0.2210 | PDE Loss: -2.7790 | Boundary Loss: -4.6009 | Data Loss: -2.1064
# Total Loss: 0.2210 | PDE Loss: -2.7824 | Boundary Loss: -4.6290 | Data Loss: -2.1042
# Total Loss: 0.2205 | PDE Loss: -2.8147 | Boundary Loss: -5.0239 | Data Loss: -2.0753
# Total Loss: 0.2205 | PDE Loss: -2.8151 | Boundary Loss: -5.0216 | Data Loss: -2.0748
# Total Loss: 0.2205 | PDE Loss: -2.8166 | Boundary Loss: -5.0152 | Data Loss: -2.0727
# Total Loss: 0.2204 | PDE Loss: -2.8228 | Boundary Loss: -4.9867 | Data Loss: -2.0637
# Total Loss: 0.2196 | PDE Loss: -2.8576 | Boundary Loss: -4.7102 | Data Loss: -1.9471
# Total Loss: 0.2196 | PDE Loss: -2.8576 | Boundary Loss: -4.7157 | Data Loss: -1.9459
# Total Loss: 0.2196 | PDE Loss: -2.8577 | Boundary Loss: -4.7428 | Data Loss: -1.9408
# Total Loss: 0.2193 | PDE Loss: -2.8538 | Boundary Loss: -5.1986 | Data Loss: -1.8828
# Total Loss: 0.2193 | PDE Loss: -2.8537 | Boundary Loss: -5.2042 | Data Loss: -1.8814
# Total Loss: 0.2192 | PDE Loss: -2.8529 | Boundary Loss: -5.2320 | Data Loss: -1.8752
# Total Loss: 0.2191 | PDE Loss: -2.8476 | Boundary Loss: -5.4142 | Data Loss: -1.8406
# Total Loss: 0.2189 | PDE Loss: -2.7747 | Boundary Loss: -3.9205 | Data Loss: -1.6452
# Total Loss: 0.2187 | PDE Loss: -2.8083 | Boundary Loss: -4.5079 | Data Loss: -1.7128
# Total Loss: 0.2187 | PDE Loss: -2.8083 | Boundary Loss: -4.5082 | Data Loss: -1.7127
# Total Loss: 0.2187 | PDE Loss: -2.8083 | Boundary Loss: -4.5084 | Data Loss: -1.7127
# Total Loss: 0.2187 | PDE Loss: -2.8083 | Boundary Loss: -4.5084 | Data Loss: -1.7127
# Total Loss: 0.2187 | PDE Loss: -2.8083 | Boundary Loss: -4.5078 | Data Loss: -1.7127
# Total Loss: 0.2187 | PDE Loss: -2.8083 | Boundary Loss: -4.5084 | Data Loss: -1.7127
# Total Loss: 0.2187 | PDE Loss: -2.8082 | Boundary Loss: -4.5077 | Data Loss: -1.7125
# Total Loss: 0.2187 | PDE Loss: -2.8082 | Boundary Loss: -4.5084 | Data Loss: -1.7117
# Total Loss: 0.2187 | PDE Loss: -2.8081 | Boundary Loss: -4.5086 | Data Loss: -1.7109
# Total Loss: 0.2186 | PDE Loss: -2.8072 | Boundary Loss: -4.5088 | Data Loss: -1.7029
# Total Loss: 0.2184 | PDE Loss: -2.8001 | Boundary Loss: -4.4407 | Data Loss: -1.6583
# Total Loss: 0.2184 | PDE Loss: -2.8001 | Boundary Loss: -4.4427 | Data Loss: -1.6581
# Total Loss: 0.2184 | PDE Loss: -2.8002 | Boundary Loss: -4.4477 | Data Loss: -1.6578
# Total Loss: 0.2184 | PDE Loss: -2.8005 | Boundary Loss: -4.4645 | Data Loss: -1.6566
# Total Loss: 0.2184 | PDE Loss: -2.8012 | Boundary Loss: -4.5214 | Data Loss: -1.6524
# Total Loss: 0.2181 | PDE Loss: -2.8027 | Boundary Loss: -4.9408 | Data Loss: -1.6253
# Total Loss: 0.2181 | PDE Loss: -2.8028 | Boundary Loss: -4.9397 | Data Loss: -1.6251
# Total Loss: 0.2180 | PDE Loss: -2.8028 | Boundary Loss: -4.9406 | Data Loss: -1.6241
# Total Loss: 0.2180 | PDE Loss: -2.8032 | Boundary Loss: -4.9378 | Data Loss: -1.6186
# Total Loss: 0.2178 | PDE Loss: -2.8036 | Boundary Loss: -4.8554 | Data Loss: -1.5917
# Total Loss: 0.2178 | PDE Loss: -2.8036 | Boundary Loss: -4.8567 | Data Loss: -1.5916
# Total Loss: 0.2178 | PDE Loss: -2.8039 | Boundary Loss: -4.8640 | Data Loss: -1.5907
# Total Loss: 0.2178 | PDE Loss: -2.8054 | Boundary Loss: -4.9027 | Data Loss: -1.5860
# Total Loss: 0.2174 | PDE Loss: -2.8101 | Boundary Loss: -5.0393 | Data Loss: -1.5487
# Total Loss: 0.2174 | PDE Loss: -2.8102 | Boundary Loss: -5.0417 | Data Loss: -1.5486
# Total Loss: 0.2174 | PDE Loss: -2.8102 | Boundary Loss: -5.0424 | Data Loss: -1.5484
# Total Loss: 0.2174 | PDE Loss: -2.8106 | Boundary Loss: -5.0490 | Data Loss: -1.5471
# Total Loss: 0.2173 | PDE Loss: -2.8116 | Boundary Loss: -5.0706 | Data Loss: -1.5423
# Total Loss: 0.2170 | PDE Loss: -2.8111 | Boundary Loss: -5.0267 | Data Loss: -1.5117
# Total Loss: 0.2170 | PDE Loss: -2.8112 | Boundary Loss: -5.0291 | Data Loss: -1.5118
# Total Loss: 0.2170 | PDE Loss: -2.8114 | Boundary Loss: -5.0319 | Data Loss: -1.5120
# Total Loss: 0.2170 | PDE Loss: -2.8119 | Boundary Loss: -5.0414 | Data Loss: -1.5126
# Total Loss: 0.2169 | PDE Loss: -2.8149 | Boundary Loss: -5.1064 | Data Loss: -1.5164
# Total Loss: 0.2163 | PDE Loss: -2.8145 | Boundary Loss: -5.3476 | Data Loss: -1.5461
# Total Loss: 0.2163 | PDE Loss: -2.8145 | Boundary Loss: -5.3510 | Data Loss: -1.5460
# Total Loss: 0.2163 | PDE Loss: -2.8146 | Boundary Loss: -5.3568 | Data Loss: -1.5460
# Total Loss: 0.2163 | PDE Loss: -2.8150 | Boundary Loss: -5.3966 | Data Loss: -1.5459
# Total Loss: 0.2161 | PDE Loss: -2.8149 | Boundary Loss: -5.6025 | Data Loss: -1.5460
# Total Loss: 0.2153 | PDE Loss: -2.7345 | Boundary Loss: -5.4039 | Data Loss: -1.5605
# Total Loss: 0.2153 | PDE Loss: -2.7343 | Boundary Loss: -5.4072 | Data Loss: -1.5603
# Total Loss: 0.2153 | PDE Loss: -2.7342 | Boundary Loss: -5.4100 | Data Loss: -1.5600
# Total Loss: 0.2153 | PDE Loss: -2.7331 | Boundary Loss: -5.4381 | Data Loss: -1.5581
# Total Loss: 0.2153 | PDE Loss: -2.7266 | Boundary Loss: -5.5334 | Data Loss: -1.5471
# Total Loss: 0.2153 | PDE Loss: -2.7265 | Boundary Loss: -5.5485 | Data Loss: -1.5466
# Total Loss: 0.2152 | PDE Loss: -2.7263 | Boundary Loss: -5.5716 | Data Loss: -1.5459
# Total Loss: 0.2152 | PDE Loss: -2.7245 | Boundary Loss: -5.7303 | Data Loss: -1.5407
# Total Loss: 0.2150 | PDE Loss: -2.7063 | Boundary Loss: -5.3446 | Data Loss: -1.5121
# Total Loss: 0.2150 | PDE Loss: -2.7062 | Boundary Loss: -5.3440 | Data Loss: -1.5119
# Total Loss: 0.2150 | PDE Loss: -2.7060 | Boundary Loss: -5.3466 | Data Loss: -1.5115
# Total Loss: 0.2150 | PDE Loss: -2.7057 | Boundary Loss: -5.3501 | Data Loss: -1.5108
# Total Loss: 0.2150 | PDE Loss: -2.7032 | Boundary Loss: -5.3802 | Data Loss: -1.5051
# Total Loss: 0.2149 | PDE Loss: -2.6912 | Boundary Loss: -5.4989 | Data Loss: -1.4825
# Total Loss: 0.2149 | PDE Loss: -2.6912 | Boundary Loss: -5.5022 | Data Loss: -1.4823
# Total Loss: 0.2149 | PDE Loss: -2.6911 | Boundary Loss: -5.5109 | Data Loss: -1.4812
# Total Loss: 0.2149 | PDE Loss: -2.6906 | Boundary Loss: -5.5546 | Data Loss: -1.4762
# Total Loss: 0.2148 | PDE Loss: -2.6859 | Boundary Loss: -5.8943 | Data Loss: -1.4480
# Total Loss: 0.2148 | PDE Loss: -2.6859 | Boundary Loss: -5.8960 | Data Loss: -1.4479
# Total Loss: 0.2148 | PDE Loss: -2.6857 | Boundary Loss: -5.8994 | Data Loss: -1.4472
# Total Loss: 0.2148 | PDE Loss: -2.6856 | Boundary Loss: -5.9012 | Data Loss: -1.4463
# Total Loss: 0.2147 | PDE Loss: -2.6838 | Boundary Loss: -5.9296 | Data Loss: -1.4384
# Total Loss: 0.2145 | PDE Loss: -2.6645 | Boundary Loss: -6.0338 | Data Loss: -1.3968
# Total Loss: 0.2145 | PDE Loss: -2.6645 | Boundary Loss: -6.0355 | Data Loss: -1.3967
# Total Loss: 0.2145 | PDE Loss: -2.6645 | Boundary Loss: -6.0363 | Data Loss: -1.3966
# Total Loss: 0.2145 | PDE Loss: -2.6646 | Boundary Loss: -6.0358 | Data Loss: -1.3965
# Total Loss: 0.2145 | PDE Loss: -2.6647 | Boundary Loss: -6.0491 | Data Loss: -1.3951
# Total Loss: 0.2145 | PDE Loss: -2.6657 | Boundary Loss: -6.1863 | Data Loss: -1.3799
# Total Loss: 0.2145 | PDE Loss: -2.6657 | Boundary Loss: -6.1860 | Data Loss: -1.3798
# Total Loss: 0.2145 | PDE Loss: -2.6658 | Boundary Loss: -6.1838 | Data Loss: -1.3797
# Total Loss: 0.2145 | PDE Loss: -2.6659 | Boundary Loss: -6.1782 | Data Loss: -1.3786
# Total Loss: 0.2144 | PDE Loss: -2.6665 | Boundary Loss: -6.1437 | Data Loss: -1.3704
# Total Loss: 0.2144 | PDE Loss: -2.6666 | Boundary Loss: -6.1456 | Data Loss: -1.3703
# Total Loss: 0.2144 | PDE Loss: -2.6667 | Boundary Loss: -6.1455 | Data Loss: -1.3702
# Total Loss: 0.2144 | PDE Loss: -2.6667 | Boundary Loss: -6.1442 | Data Loss: -1.3702
# Total Loss: 0.2144 | PDE Loss: -2.6673 | Boundary Loss: -6.1460 | Data Loss: -1.3692
# Total Loss: 0.2144 | PDE Loss: -2.6694 | Boundary Loss: -6.1507 | Data Loss: -1.3655
# Total Loss: 0.2142 | PDE Loss: -2.6788 | Boundary Loss: -6.1347 | Data Loss: -1.3440
# Total Loss: 0.2142 | PDE Loss: -2.6789 | Boundary Loss: -6.1354 | Data Loss: -1.3439
# Total Loss: 0.2142 | PDE Loss: -2.6790 | Boundary Loss: -6.1335 | Data Loss: -1.3437
# Total Loss: 0.2142 | PDE Loss: -2.6800 | Boundary Loss: -6.1261 | Data Loss: -1.3420
# Total Loss: 0.2141 | PDE Loss: -2.6823 | Boundary Loss: -6.0825 | Data Loss: -1.3337
# Total Loss: 0.2141 | PDE Loss: -2.6823 | Boundary Loss: -6.0826 | Data Loss: -1.3336
# Total Loss: 0.2141 | PDE Loss: -2.6824 | Boundary Loss: -6.0817 | Data Loss: -1.3335
# Total Loss: 0.2141 | PDE Loss: -2.6828 | Boundary Loss: -6.0777 | Data Loss: -1.3326
# Total Loss: 0.2140 | PDE Loss: -2.6843 | Boundary Loss: -6.0622 | Data Loss: -1.3299
# Total Loss: 0.2138 | PDE Loss: -2.6889 | Boundary Loss: -5.9526 | Data Loss: -1.3136
# Total Loss: 0.2138 | PDE Loss: -2.6889 | Boundary Loss: -5.9538 | Data Loss: -1.3136
# Total Loss: 0.2138 | PDE Loss: -2.6888 | Boundary Loss: -5.9512 | Data Loss: -1.3134
# Total Loss: 0.2138 | PDE Loss: -2.6885 | Boundary Loss: -5.9470 | Data Loss: -1.3130
# Total Loss: 0.2137 | PDE Loss: -2.6859 | Boundary Loss: -5.9106 | Data Loss: -1.3103
# Total Loss: 0.2134 | PDE Loss: -2.6481 | Boundary Loss: -5.6150 | Data Loss: -1.3035
# Total Loss: 0.2134 | PDE Loss: -2.6481 | Boundary Loss: -5.6153 | Data Loss: -1.3034
# Total Loss: 0.2133 | PDE Loss: -2.6480 | Boundary Loss: -5.6196 | Data Loss: -1.3030
# Total Loss: 0.2133 | PDE Loss: -2.6479 | Boundary Loss: -5.6296 | Data Loss: -1.3023
# Total Loss: 0.2133 | PDE Loss: -2.6463 | Boundary Loss: -5.6843 | Data Loss: -1.2968
# Total Loss: 0.2130 | PDE Loss: -2.6226 | Boundary Loss: -5.6909 | Data Loss: -1.2692
# Total Loss: 0.2130 | PDE Loss: -2.6224 | Boundary Loss: -5.6917 | Data Loss: -1.2692
# Total Loss: 0.2130 | PDE Loss: -2.6214 | Boundary Loss: -5.6968 | Data Loss: -1.2691
# Total Loss: 0.2130 | PDE Loss: -2.6175 | Boundary Loss: -5.7091 | Data Loss: -1.2687
# Total Loss: 0.2128 | PDE Loss: -2.5934 | Boundary Loss: -5.6020 | Data Loss: -1.2677
# Total Loss: 0.2128 | PDE Loss: -2.5932 | Boundary Loss: -5.6021 | Data Loss: -1.2677
# Total Loss: 0.2128 | PDE Loss: -2.5930 | Boundary Loss: -5.6016 | Data Loss: -1.2677
# Total Loss: 0.2128 | PDE Loss: -2.5925 | Boundary Loss: -5.6006 | Data Loss: -1.2677
# Total Loss: 0.2128 | PDE Loss: -2.5879 | Boundary Loss: -5.5952 | Data Loss: -1.2676
# Total Loss: 0.2126 | PDE Loss: -2.5549 | Boundary Loss: -5.5084 | Data Loss: -1.2694
# Total Loss: 0.2126 | PDE Loss: -2.5547 | Boundary Loss: -5.5085 | Data Loss: -1.2692
# Total Loss: 0.2126 | PDE Loss: -2.5537 | Boundary Loss: -5.5086 | Data Loss: -1.2687
# Total Loss: 0.2125 | PDE Loss: -2.5484 | Boundary Loss: -5.5070 | Data Loss: -1.2660
# Total Loss: 0.2122 | PDE Loss: -2.5163 | Boundary Loss: -5.3728 | Data Loss: -1.2538
# Total Loss: 0.2122 | PDE Loss: -2.5160 | Boundary Loss: -5.3730 | Data Loss: -1.2539
# Total Loss: 0.2122 | PDE Loss: -2.5154 | Boundary Loss: -5.3734 | Data Loss: -1.2539
# Total Loss: 0.2122 | PDE Loss: -2.5115 | Boundary Loss: -5.3770 | Data Loss: -1.2544
# Total Loss: 0.2118 | PDE Loss: -2.4729 | Boundary Loss: -5.3001 | Data Loss: -1.2630
# Total Loss: 0.2118 | PDE Loss: -2.4727 | Boundary Loss: -5.3002 | Data Loss: -1.2629
# Total Loss: 0.2118 | PDE Loss: -2.4716 | Boundary Loss: -5.2995 | Data Loss: -1.2624
# Total Loss: 0.2116 | PDE Loss: -2.4592 | Boundary Loss: -5.2815 | Data Loss: -1.2578
# Total Loss: 0.2102 | PDE Loss: -2.2888 | Boundary Loss: -4.6815 | Data Loss: -1.2772
# Total Loss: 0.2102 | PDE Loss: -2.2888 | Boundary Loss: -4.6814 | Data Loss: -1.2771
# Total Loss: 0.2102 | PDE Loss: -2.2888 | Boundary Loss: -4.6817 | Data Loss: -1.2767
# Total Loss: 0.2102 | PDE Loss: -2.2883 | Boundary Loss: -4.6832 | Data Loss: -1.2745
# Total Loss: 0.2096 | PDE Loss: -2.2766 | Boundary Loss: -4.6362 | Data Loss: -1.2499
# Total Loss: 0.2096 | PDE Loss: -2.2763 | Boundary Loss: -4.6392 | Data Loss: -1.2500
# Total Loss: 0.2096 | PDE Loss: -2.2757 | Boundary Loss: -4.6443 | Data Loss: -1.2502
# Total Loss: 0.2095 | PDE Loss: -2.2717 | Boundary Loss: -4.6770 | Data Loss: -1.2513
# Total Loss: 0.2088 | PDE Loss: -2.2203 | Boundary Loss: -4.2309 | Data Loss: -1.2756
# Total Loss: 0.2088 | PDE Loss: -2.2203 | Boundary Loss: -4.2317 | Data Loss: -1.2756
# Total Loss: 0.2087 | PDE Loss: -2.2203 | Boundary Loss: -4.2322 | Data Loss: -1.2756
# Total Loss: 0.2087 | PDE Loss: -2.2203 | Boundary Loss: -4.2380 | Data Loss: -1.2753
# Total Loss: 0.2085 | PDE Loss: -2.2200 | Boundary Loss: -4.2620 | Data Loss: -1.2742
# Total Loss: 0.2069 | PDE Loss: -2.1876 | Boundary Loss: -4.6051 | Data Loss: -1.2573
# Total Loss: 0.2069 | PDE Loss: -2.1874 | Boundary Loss: -4.6044 | Data Loss: -1.2574
# Total Loss: 0.2069 | PDE Loss: -2.1867 | Boundary Loss: -4.6031 | Data Loss: -1.2582
# Total Loss: 0.2068 | PDE Loss: -2.1824 | Boundary Loss: -4.5930 | Data Loss: -1.2625
# Total Loss: 0.2058 | PDE Loss: -2.1349 | Boundary Loss: -4.2606 | Data Loss: -1.3156
# Total Loss: 0.2058 | PDE Loss: -2.1348 | Boundary Loss: -4.2633 | Data Loss: -1.3158
# Total Loss: 0.2058 | PDE Loss: -2.1346 | Boundary Loss: -4.2660 | Data Loss: -1.3160
# Total Loss: 0.2058 | PDE Loss: -2.1334 | Boundary Loss: -4.2898 | Data Loss: -1.3179
# Total Loss: 0.2054 | PDE Loss: -2.1250 | Boundary Loss: -4.4405 | Data Loss: -1.3287
# Total Loss: 0.2054 | PDE Loss: -2.1249 | Boundary Loss: -4.4414 | Data Loss: -1.3290
# Total Loss: 0.2054 | PDE Loss: -2.1245 | Boundary Loss: -4.4422 | Data Loss: -1.3298
# ...
# Total Loss: -3.0593 | PDE Loss: -3.5793 | Boundary Loss: -7.3705 | Data Loss: -4.9265
# Total Loss: -3.0593 | PDE Loss: -3.5793 | Boundary Loss: -7.3414 | Data Loss: -4.9271
# Total Loss: -3.0593 | PDE Loss: -3.5793 | Boundary Loss: -7.3354 | Data Loss: -4.9270
# Total Loss: -3.0593 | PDE Loss: -3.5793 | Boundary Loss: -7.3424 | Data Loss: -4.9270
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3453 | Data Loss: -4.9265
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3460 | Data Loss: -4.9233
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3406 | Data Loss: -4.9234
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3340 | Data Loss: -4.9240
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3429 | Data Loss: -4.9247
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3356 | Data Loss: -4.9255
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3312 | Data Loss: -4.9268
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3257 | Data Loss: -4.9268
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3307 | Data Loss: -4.9268
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3308 | Data Loss: -4.9268
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3307 | Data Loss: -4.9268
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3307 | Data Loss: -4.9268
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3307 | Data Loss: -4.9268
# Total Loss: -3.0593 | PDE Loss: -3.5794 | Boundary Loss: -7.3355 | Data Loss: -4.9269
# Total Loss: -3.0593 | PDE Loss: -3.5795 | Boundary Loss: -7.3388 | Data Loss: -4.9273
# Total Loss: -3.0593 | PDE Loss: -3.5795 | Boundary Loss: -7.3315 | Data Loss: -4.9281
# Total Loss: -3.0593 | PDE Loss: -3.5795 | Boundary Loss: -7.3370 | Data Loss: -4.9282
# Total Loss: -3.0593 | PDE Loss: -3.5795 | Boundary Loss: -7.3372 | Data Loss: -4.9281
# Total Loss: -3.0593 | PDE Loss: -3.5795 | Boundary Loss: -7.3412 | Data Loss: -4.9285
# Total Loss: -3.0593 | PDE Loss: -3.5795 | Boundary Loss: -7.3352 | Data Loss: -4.9293
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3253 | Data Loss: -4.9331
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3255 | Data Loss: -4.9331
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3224 | Data Loss: -4.9330
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3153 | Data Loss: -4.9324
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3018 | Data Loss: -4.9302
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3001 | Data Loss: -4.9301
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3003 | Data Loss: -4.9302
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3003 | Data Loss: -4.9302
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3003 | Data Loss: -4.9302
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.3067 | Data Loss: -4.9301
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.2912 | Data Loss: -4.9301
# Total Loss: -3.0594 | PDE Loss: -3.5796 | Boundary Loss: -7.2907 | Data Loss: -4.9299
# Total Loss: -3.0594 | PDE Loss: -3.5797 | Boundary Loss: -7.2729 | Data Loss: -4.9290
# Total Loss: -3.0594 | PDE Loss: -3.5797 | Boundary Loss: -7.2675 | Data Loss: -4.9289
# Total Loss: -3.0594 | PDE Loss: -3.5797 | Boundary Loss: -7.2664 | Data Loss: -4.9290
# Total Loss: -3.0594 | PDE Loss: -3.5797 | Boundary Loss: -7.2711 | Data Loss: -4.9291
# Total Loss: -3.0595 | PDE Loss: -3.5797 | Boundary Loss: -7.2940 | Data Loss: -4.9302
# Total Loss: -3.0595 | PDE Loss: -3.5797 | Boundary Loss: -7.2986 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2990 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2990 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2990 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5797 | Boundary Loss: -7.2954 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5797 | Boundary Loss: -7.2891 | Data Loss: -4.9304
# Total Loss: -3.0595 | PDE Loss: -3.5797 | Boundary Loss: -7.2891 | Data Loss: -4.9304
# Total Loss: -3.0595 | PDE Loss: -3.5797 | Boundary Loss: -7.2891 | Data Loss: -4.9304
# Total Loss: -3.0595 | PDE Loss: -3.5797 | Boundary Loss: -7.2976 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2974 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2924 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2974 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2922 | Data Loss: -4.9303
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2883 | Data Loss: -4.9302
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2828 | Data Loss: -4.9297
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2209 | Data Loss: -4.9267
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2219 | Data Loss: -4.9267
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2256 | Data Loss: -4.9265
# Total Loss: -3.0595 | PDE Loss: -3.5798 | Boundary Loss: -7.2217 | Data Loss: -4.9264
# Total Loss: -3.0595 | PDE Loss: -3.5799 | Boundary Loss: -7.2088 | Data Loss: -4.9254
# Total Loss: -3.0595 | PDE Loss: -3.5799 | Boundary Loss: -7.1908 | Data Loss: -4.9240
# Total Loss: -3.0595 | PDE Loss: -3.5799 | Boundary Loss: -7.1908 | Data Loss: -4.9239
# Total Loss: -3.0595 | PDE Loss: -3.5799 | Boundary Loss: -7.1901 | Data Loss: -4.9240
# Total Loss: -3.0595 | PDE Loss: -3.5799 | Boundary Loss: -7.1951 | Data Loss: -4.9239
# Total Loss: -3.0595 | PDE Loss: -3.5799 | Boundary Loss: -7.1915 | Data Loss: -4.9237
# Total Loss: -3.0595 | PDE Loss: -3.5799 | Boundary Loss: -7.1825 | Data Loss: -4.9232
# Total Loss: -3.0595 | PDE Loss: -3.5800 | Boundary Loss: -7.1420 | Data Loss: -4.9195
# Total Loss: -3.0595 | PDE Loss: -3.5800 | Boundary Loss: -7.1329 | Data Loss: -4.9194
# Total Loss: -3.0595 | PDE Loss: -3.5800 | Boundary Loss: -7.1456 | Data Loss: -4.9196
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.1694 | Data Loss: -4.9205
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2707 | Data Loss: -4.9244
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2662 | Data Loss: -4.9243
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2670 | Data Loss: -4.9242
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2614 | Data Loss: -4.9241
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2583 | Data Loss: -4.9241
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2569 | Data Loss: -4.9240
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2614 | Data Loss: -4.9241
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2673 | Data Loss: -4.9241
# Total Loss: -3.0596 | PDE Loss: -3.5799 | Boundary Loss: -7.2620 | Data Loss: -4.9240
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2618 | Data Loss: -4.9231
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2443 | Data Loss: -4.9176
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2437 | Data Loss: -4.9178
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2380 | Data Loss: -4.9176
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2380 | Data Loss: -4.9176
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2380 | Data Loss: -4.9176
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2290 | Data Loss: -4.9176
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2387 | Data Loss: -4.9177
# Total Loss: -3.0596 | PDE Loss: -3.5800 | Boundary Loss: -7.2319 | Data Loss: -4.9173
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1913 | Data Loss: -4.9166
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1904 | Data Loss: -4.9165
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1949 | Data Loss: -4.9165
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1904 | Data Loss: -4.9166
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1947 | Data Loss: -4.9166
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1949 | Data Loss: -4.9165
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1949 | Data Loss: -4.9165
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1920 | Data Loss: -4.9165
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1878 | Data Loss: -4.9158
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1830 | Data Loss: -4.9140
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1834 | Data Loss: -4.9140
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1875 | Data Loss: -4.9141
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1875 | Data Loss: -4.9141
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1875 | Data Loss: -4.9141
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1875 | Data Loss: -4.9141
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1928 | Data Loss: -4.9139
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1866 | Data Loss: -4.9139
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.1985 | Data Loss: -4.9140
# Total Loss: -3.0597 | PDE Loss: -3.5801 | Boundary Loss: -7.2031 | Data Loss: -4.9136
# Total Loss: -3.0597 | PDE Loss: -3.5800 | Boundary Loss: -7.3154 | Data Loss: -4.9112
# Total Loss: -3.0597 | PDE Loss: -3.5800 | Boundary Loss: -7.3058 | Data Loss: -4.9113
# Total Loss: -3.0597 | PDE Loss: -3.5800 | Boundary Loss: -7.3009 | Data Loss: -4.9110
# Total Loss: -3.0597 | PDE Loss: -3.5800 | Boundary Loss: -7.2917 | Data Loss: -4.9111
# Total Loss: -3.0597 | PDE Loss: -3.5802 | Boundary Loss: -7.1887 | Data Loss: -4.9101
# Total Loss: -3.0597 | PDE Loss: -3.5802 | Boundary Loss: -7.1884 | Data Loss: -4.9101
# Total Loss: -3.0597 | PDE Loss: -3.5802 | Boundary Loss: -7.1874 | Data Loss: -4.9101
# Total Loss: -3.0597 | PDE Loss: -3.5802 | Boundary Loss: -7.1874 | Data Loss: -4.9101
# Total Loss: -3.0597 | PDE Loss: -3.5802 | Boundary Loss: -7.1874 | Data Loss: -4.9101
# Total Loss: -3.0597 | PDE Loss: -3.5802 | Boundary Loss: -7.1840 | Data Loss: -4.9101
# Total Loss: -3.0597 | PDE Loss: -3.5802 | Boundary Loss: -7.1813 | Data Loss: -4.9102
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1755 | Data Loss: -4.9103
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1752 | Data Loss: -4.9103
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1737 | Data Loss: -4.9104
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1737 | Data Loss: -4.9103
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1737 | Data Loss: -4.9104
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1737 | Data Loss: -4.9104
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1702 | Data Loss: -4.9103
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1709 | Data Loss: -4.9103
# Total Loss: -3.0598 | PDE Loss: -3.5802 | Boundary Loss: -7.1734 | Data Loss: -4.9102
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1614 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1616 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1571 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1571 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1571 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1576 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1576 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1576 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1576 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1569 | Data Loss: -4.9093
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1607 | Data Loss: -4.9094
# Total Loss: -3.0598 | PDE Loss: -3.5803 | Boundary Loss: -7.1590 | Data Loss: -4.9095
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.2028 | Data Loss: -4.9103
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1988 | Data Loss: -4.9103
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1983 | Data Loss: -4.9104
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1911 | Data Loss: -4.9106
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1926 | Data Loss: -4.9106
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1947 | Data Loss: -4.9107
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1947 | Data Loss: -4.9107
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1947 | Data Loss: -4.9107
# Total Loss: -3.0598 | PDE Loss: -3.5804 | Boundary Loss: -7.1839 | Data Loss: -4.9106
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1564 | Data Loss: -4.9098
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1526 | Data Loss: -4.9098
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1530 | Data Loss: -4.9098
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1530 | Data Loss: -4.9098
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1530 | Data Loss: -4.9098
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1534 | Data Loss: -4.9099
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1571 | Data Loss: -4.9102
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1526 | Data Loss: -4.9101
# Total Loss: -3.0599 | PDE Loss: -3.5805 | Boundary Loss: -7.1473 | Data Loss: -4.9110
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1289 | Data Loss: -4.9160
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1283 | Data Loss: -4.9161
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1277 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1319 | Data Loss: -4.9161
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1315 | Data Loss: -4.9161
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1277 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1277 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1277 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1281 | Data Loss: -4.9161
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1321 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1321 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1321 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1323 | Data Loss: -4.9162
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1367 | Data Loss: -4.9165
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1515 | Data Loss: -4.9180
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1874 | Data Loss: -4.9211
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1825 | Data Loss: -4.9212
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1874 | Data Loss: -4.9214
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1800 | Data Loss: -4.9215
# Total Loss: -3.0599 | PDE Loss: -3.5808 | Boundary Loss: -7.1603 | Data Loss: -4.9233
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1606 | Data Loss: -4.9233
# Total Loss: -3.0599 | PDE Loss: -3.5807 | Boundary Loss: -7.1610 | Data Loss: -4.9234
# Total Loss: -3.0599 | PDE Loss: -3.5808 | Boundary Loss: -7.1667 | Data Loss: -4.9234
# Total Loss: -3.0599 | PDE Loss: -3.5808 | Boundary Loss: -7.1762 | Data Loss: -4.9234
# Total Loss: -3.0599 | PDE Loss: -3.5808 | Boundary Loss: -7.1729 | Data Loss: -4.9234
# Total Loss: -3.0599 | PDE Loss: -3.5808 | Boundary Loss: -7.1723 | Data Loss: -4.9235
# Total Loss: -3.0599 | PDE Loss: -3.5808 | Boundary Loss: -7.1723 | Data Loss: -4.9235
# Final Loss: -3.059949
# Relative L2 Error: 0.029833%
