# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.profiler import profile, record_function, ProfilerActivity
from numpy import log 

torch.manual_seed(123)

# %%
# Generalisable NN
torch.manual_seed(32)

class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed):
        super().__init__()

        # Define size of input and output layers
        self.input_dim = input_dim
        self.output_dim = output_dim

        # Define size of hidden layers (number of neurons)
        self.layer_dim = layer_dim

        # Define how many hidden layers
        self.num_hidden = num_hidden

        # Define activation function of neurons 
        self.activation = nn.Tanh()

        # Define regularisation parameter
        self.reg_param = reg_param

        # Defin regularisation exponent power
        self.reg_power = reg_power

        # Define random seed to be used
        self.ran_seed = ran_seed

        # Build architectyre
        self.input_layer = nn.Linear(self.input_dim, self.layer_dim)
        self.hidden_layers = nn.ModuleList([nn.Linear(self.layer_dim, self.layer_dim) for _ in range(num_hidden-1)])
        self.output_layer = nn.Linear(self.layer_dim, self.output_dim)
        self.layers = nn.ModuleList([self.input_layer, *self.hidden_layers, self.output_layer])

        # Initialise weights
        self.initialise()

    def forward(self, x):
    # Function defines the forward pass of the network
        for _, f in enumerate(self.layers[:-1]):
            x = self.activation(f(x))
        x = self.output_layer(x)
        return x
    
    def initialise(self):
    # Function defines initilaising the unfrozen weights of the network using Xavier (Glorot) initialisiation
        torch.manual_seed(self.ran_seed)
        def init_weights(m):
            if type(m) == nn.Linear and m.weight.requires_grad and m.bias.requires_grad:
                g = nn.init.calculate_gain('tanh')
                #torch.nn.init.xavier_uniform_(m.weight, gain=g)
                torch.nn.init.xavier_normal_(m.weight, gain=g)
                m.bias.data.fill_(0)

        self.apply(init_weights)

    def regularization(self):
    # Function defines regularisation
        reg_loss = 0
        for name, param in self.named_parameters():
            if 'weight' in name:
                reg_loss = reg_loss + torch.norm(param, self.reg_power)
        return self.reg_param * reg_loss

# %%
# Define the PINN class
class PINN(nn.Module):
    def __init__(self, balancing_parameter, input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed):
        super(PINN, self).__init__()

        # Initialize the NeuralNetwork for intensity and absorption coefficient
        self.intensity_network = NeuralNetwork(input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed)
        self.emission_network = NeuralNetwork(input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed)

        self.balancing_parameter = balancing_parameter


    def compute_pde_residual(self, input_distance):
            '''
            Enforces PDE via automatic differentiation.
            Uses NN to predict intensity and absorption, and calculates dI/ds.
            '''
            input_distance.requires_grad = True

            # Predict intensity and absorption coefficient
            pred_intensity = self.intensity_network(input_distance)
            emission = self.emission_network(input_distance)

            # Compute derivative dI/ds using autograd
            dintensity = torch.autograd.grad(pred_intensity.sum(), input_distance, create_graph=True)[0]

            # PDE residual: dI/ds + alpha * I = 0
            residual = dintensity - emission

            return residual.reshape(-1,)
    
    def compute_loss(self, dist_bound, int_bound, input_distance, input_intensity, input_emission, verbose=True):
        '''
        Computes loss using boundary conditions, physics residuals, and data loss.
        '''
        # Predict intensity at boundaries
        #pred_initial_intensity = self.intensity_network(dist_bound[0])
        pred_boundary_intensity = self.intensity_network(dist_bound)
        pred_boundary_emission = self.emission_network(dist_bound)

        # Compute PDE residuals (physics enforcement)
        physics_residual = self.compute_pde_residual(input_distance)

        # **Hard enforce boundary conditions**
        #boundary_loss = torch.mean((pred_initial_intensity - int_bound[0])**2)

        boundary_loss = torch.mean((pred_boundary_intensity - int_bound)**2)
        #boundary_loss_2 = torch.mean((pred_boundary_emission - input_emission)**2)

        # Compute data residuals inside the slab
        pred_intensity = self.intensity_network(input_distance)
        #pred_emission = self.emission_network(input_distance)
        data_residual = input_intensity - pred_intensity
        #data_residual_2 = input_emission - pred_emission

        # Compute loss terms (L2 loss)
        physics_loss = torch.mean(abs(physics_residual)**2)
        data_loss = torch.mean(abs(data_residual)**2)
        #data_loss_2 = torch.mean(abs(data_residual_2)**2)

        # Add regularization terms
        intensity_reg = self.intensity_network.regularization()
        emission_reg = self.emission_network.regularization()
        

        # Total loss (weighted combination)
        total_loss = torch.log(self.balancing_parameter * (data_loss+boundary_loss) + physics_loss + intensity_reg + emission_reg)
        
        if verbose:
            print(f"Total Loss: {total_loss.item():.4f} | PDE Loss: {torch.log10(physics_loss).item():.4f} | "
                f"Boundary Loss: {torch.log10(boundary_loss).item():.4f} | Data Loss: {torch.log10(data_loss).item():.4f}")
        
        return total_loss
    

# Define the function for the analytical solution
def analytical_solution(input_distance, emission_value, I0=0.0):
    return I0 + emission_value*input_distance

def plot_results(model, input_distance, analytical_solution, emission_value):
    # Predict intensity from the trained model
    pred_intensity = model.intensity_network(input_distance).detach()

    # Compute the analytical solution using the true alpha value
    anal_intensity = analytical_solution(input_distance, emission_value)

    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(input_distance.detach().numpy(), pred_intensity.detach().numpy(), label='Predicted Intensity', color='b')
    plt.plot(input_distance.detach().numpy(), anal_intensity.detach().numpy(), label='Analytical Intensity', color='r', linestyle='--')
    plt.xlabel('Distance (s)')
    plt.ylabel('Intensity')
    plt.legend()
    plt.title('Intensity Prediction vs Analytical Solution')
    plt.show()

    pred_emission = model.emission_network(input_distance).detach().numpy().flatten()

    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(input_distance.detach().numpy(), pred_emission, label='Predicted emission', color='b')
    plt.axhline(y=emission_value, color='r', linestyle='--', label=f'True emission ({emission_value})')
    plt.xlabel('Distance (s)')
    plt.ylabel('emission (j)')
    plt.legend()
    plt.title('Predicted vs Analytical emission')
    plt.show()

def fit(model, optimizer, dist_bound, int_bound, input_distance, input_intensity,input_emission, epochs):
    '''
    Fits the PINN model using Adam optimization.
    '''
    history = []  # Store loss values

    for epoch in range(epochs):
        def closure():
            optimizer.zero_grad()
            loss = model.compute_loss(dist_bound, int_bound, input_distance, input_intensity, input_emission)
            loss.backward()
            history.append(loss.item())  # Store loss at each epoch
            return loss

        optimizer.step(closure)

        if epoch % 10 == 0:
            print(f"Epoch {epoch}, Loss: {history[-1]:.6f}")

    print(f"Final Loss: {history[-1]:.6f}")

def calculate_relative_l2_error(model, input_distance, analytical_solution, emission_value):
    """
    Calculates the relative L2 error between the predicted intensity and the analytical solution as a percentage.
    """
    # Predict intensity from the trained model
    pred_intensity = model.intensity_network(input_distance).detach().flatten()

    # Compute the analytical solution using the true alpha value
    anal_intensity = analytical_solution(input_distance, emission_value).flatten()

    # Compute the L2 norm of the difference between predicted and analytical solutions
    numerator = torch.norm(pred_intensity - anal_intensity, p=2)

    # Compute the L2 norm of the analytical solution
    denominator = torch.norm(anal_intensity, p=2)

    # Compute the relative L2 error as a percentage
    relative_l2_error = (numerator / denominator) * 100

    return relative_l2_error.item()

# ==== Initialize Model and Training ==== 
balancing_parameter = 10.0  # Adjust this if needed
input_dim = 1
output_dim = 1
layer_dim = 20
num_hidden = 6
reg_param = 0.001
reg_power = 1
ran_seed = 32

model = PINN(balancing_parameter, input_dim, output_dim, layer_dim, num_hidden, reg_param, reg_power, ran_seed)

optimizer_Adam = optim.Adam(
    list(model.intensity_network.parameters()) + list(model.emission_network.parameters()),
    lr=1e-3,  # Adam optimizer typically uses learning rates like this
    betas=(0.5, 0.999),  # Lower momentum for better convergence
    eps=1e-8,  # Small value to prevent division by zero
    weight_decay=0  # LBFGS doesn't typically use weight decay, so keep it 0
)

# Define LBFGS optimizer
optimizer_LBFGS = optim.LBFGS(
    list(model.intensity_network.parameters()) + list(model.emission_network.parameters()),
    lr=1e-3,
    max_iter=1000,
    max_eval=50000,
    history_size=150,
    line_search_fn="strong_wolfe",
    tolerance_change=np.finfo(float).eps
)

# ==== Training Data (Example Boundaries and Grid Points) ==== 
I0 = 0.0  # Initial intensity
emission_value = 2.0  # Absorption coefficient

dist_bound = torch.tensor([[0.0], [10.0]])  # Slab distance from 0 to 10
int_bound = torch.tensor([[I0], [I0 + emission_value*10]])  # Intensity at boundaries
x_min = dist_bound.min().item()
x_max = dist_bound.max().item()
input_distance = torch.linspace(x_min, x_max, 100).view(-1, 1)  # Interior grid

input_intensity = analytical_solution(input_distance, emission_value)

# Train the model
fit(model, optimizer_LBFGS, dist_bound, int_bound, input_distance, input_intensity, emission_value, epochs=10)

# Calculate relative L2 error as a percentage
relative_l2_error = calculate_relative_l2_error(model, input_distance, analytical_solution, emission_value)
print(f"Relative L2 Error: {relative_l2_error:.6f}%")

# Plot the results **only once** after training
plot_results(model, input_distance, analytical_solution,emission_value)
# Out:
# Total Loss: 8.0758 | PDE Loss: -0.7806 | Boundary Loss: 2.2853 | Data Loss: 2.1091
# Total Loss: 8.0757 | PDE Loss: -0.7804 | Boundary Loss: 2.2853 | Data Loss: 2.1090
# Total Loss: 8.0756 | PDE Loss: -0.7801 | Boundary Loss: 2.2852 | Data Loss: 2.1090
# Total Loss: 8.0749 | PDE Loss: -0.7780 | Boundary Loss: 2.2849 | Data Loss: 2.1086
# Total Loss: 8.0667 | PDE Loss: -0.7547 | Boundary Loss: 2.2818 | Data Loss: 2.1044
# Total Loss: 7.9836 | PDE Loss: -0.4892 | Boundary Loss: 2.2506 | Data Loss: 2.0608
# Total Loss: 7.8716 | PDE Loss: -0.0572 | Boundary Loss: 2.2111 | Data Loss: 1.9973
# Total Loss: 7.8712 | PDE Loss: -0.0559 | Boundary Loss: 2.2109 | Data Loss: 1.9971
# Total Loss: 7.8679 | PDE Loss: -0.0438 | Boundary Loss: 2.2098 | Data Loss: 1.9952
# Total Loss: 7.8372 | PDE Loss: 0.0697 | Boundary Loss: 2.1989 | Data Loss: 1.9778
# Total Loss: 7.8368 | PDE Loss: 0.0713 | Boundary Loss: 2.1987 | Data Loss: 1.9775
# Total Loss: 7.8349 | PDE Loss: 0.0785 | Boundary Loss: 2.1980 | Data Loss: 1.9764
# Total Loss: 7.8140 | PDE Loss: 0.1551 | Boundary Loss: 2.1903 | Data Loss: 1.9649
# Total Loss: 7.7182 | PDE Loss: 0.4766 | Boundary Loss: 2.1550 | Data Loss: 1.9116
# Total Loss: 7.7170 | PDE Loss: 0.4803 | Boundary Loss: 2.1546 | Data Loss: 1.9109
# Total Loss: 7.7067 | PDE Loss: 0.5128 | Boundary Loss: 2.1508 | Data Loss: 1.9051
# Total Loss: 7.6561 | PDE Loss: 0.6604 | Boundary Loss: 2.1320 | Data Loss: 1.8766
# Total Loss: 7.4024 | PDE Loss: 1.1911 | Boundary Loss: 2.0315 | Data Loss: 1.7387
# Total Loss: 7.3992 | PDE Loss: 1.1957 | Boundary Loss: 2.0302 | Data Loss: 1.7370
# Total Loss: 7.3851 | PDE Loss: 1.2163 | Boundary Loss: 2.0243 | Data Loss: 1.7296
# Total Loss: 7.2343 | PDE Loss: 1.4213 | Boundary Loss: 1.9590 | Data Loss: 1.6520
# Total Loss: 6.8913 | PDE Loss: 2.2055 | Boundary Loss: 1.6684 | Data Loss: 1.5514
# Total Loss: 6.8904 | PDE Loss: 2.2057 | Boundary Loss: 1.6674 | Data Loss: 1.5515
# Total Loss: 6.8822 | PDE Loss: 2.2077 | Boundary Loss: 1.6581 | Data Loss: 1.5529
# Total Loss: 6.7997 | PDE Loss: 2.2199 | Boundary Loss: 1.5578 | Data Loss: 1.5672
# Total Loss: 6.6612 | PDE Loss: 2.0015 | Boundary Loss: 1.3970 | Data Loss: 1.6340
# Total Loss: 6.6611 | PDE Loss: 2.0015 | Boundary Loss: 1.3970 | Data Loss: 1.6339
# Total Loss: 6.6603 | PDE Loss: 2.0014 | Boundary Loss: 1.3971 | Data Loss: 1.6332
# Total Loss: 6.6561 | PDE Loss: 2.0011 | Boundary Loss: 1.3977 | Data Loss: 1.6296
# Total Loss: 6.6303 | PDE Loss: 2.0010 | Boundary Loss: 1.4245 | Data Loss: 1.5916
# Total Loss: 6.6303 | PDE Loss: 2.0009 | Boundary Loss: 1.4245 | Data Loss: 1.5916
# Total Loss: 6.6303 | PDE Loss: 2.0008 | Boundary Loss: 1.4245 | Data Loss: 1.5916
# Total Loss: 6.6299 | PDE Loss: 1.9999 | Boundary Loss: 1.4244 | Data Loss: 1.5916
# Total Loss: 6.6256 | PDE Loss: 1.9908 | Boundary Loss: 1.4230 | Data Loss: 1.5913
# Total Loss: 6.6064 | PDE Loss: 1.9491 | Boundary Loss: 1.4168 | Data Loss: 1.5894
# Total Loss: 6.6062 | PDE Loss: 1.9488 | Boundary Loss: 1.4168 | Data Loss: 1.5894
# Total Loss: 6.6049 | PDE Loss: 1.9456 | Boundary Loss: 1.4162 | Data Loss: 1.5893
# Total Loss: 6.5913 | PDE Loss: 1.9135 | Boundary Loss: 1.4111 | Data Loss: 1.5887
# Total Loss: 6.5261 | PDE Loss: 1.7346 | Boundary Loss: 1.3879 | Data Loss: 1.5832
# Total Loss: 6.5251 | PDE Loss: 1.7319 | Boundary Loss: 1.3873 | Data Loss: 1.5831
# Total Loss: 6.5160 | PDE Loss: 1.7076 | Boundary Loss: 1.3824 | Data Loss: 1.5826
# Total Loss: 6.4712 | PDE Loss: 1.5879 | Boundary Loss: 1.3582 | Data Loss: 1.5777
# Total Loss: 6.1037 | PDE Loss: 0.9626 | Boundary Loss: 1.2377 | Data Loss: 1.4220
# Total Loss: 8.5422 | PDE Loss: 0.3845 | Boundary Loss: 2.4628 | Data Loss: 2.3464
# Total Loss: 5.4893 | PDE Loss: 0.4909 | Boundary Loss: 1.2296 | Data Loss: 0.8331
# Total Loss: 5.7750 | PDE Loss: 0.2017 | Boundary Loss: 1.3865 | Data Loss: 0.8799
# Total Loss: 5.4663 | PDE Loss: 0.4373 | Boundary Loss: 1.2470 | Data Loss: 0.7484
# Total Loss: 5.4625 | PDE Loss: 0.4277 | Boundary Loss: 1.2493 | Data Loss: 0.7346
# Total Loss: 5.4619 | PDE Loss: 0.4277 | Boundary Loss: 1.2490 | Data Loss: 0.7342
# Total Loss: 5.4567 | PDE Loss: 0.4275 | Boundary Loss: 1.2469 | Data Loss: 0.7314
# Total Loss: 5.4306 | PDE Loss: 0.4266 | Boundary Loss: 1.2363 | Data Loss: 0.7168
# Total Loss: 5.1385 | PDE Loss: 0.4141 | Boundary Loss: 1.1193 | Data Loss: 0.5446
# Total Loss: 6.7042 | PDE Loss: -0.2583 | Boundary Loss: 1.6548 | Data Loss: 1.5592
# Total Loss: 4.7098 | PDE Loss: 0.3816 | Boundary Loss: 0.9518 | Data Loss: 0.2533
# Total Loss: 4.6941 | PDE Loss: 0.3811 | Boundary Loss: 0.9451 | Data Loss: 0.2442
# Total Loss: 4.5612 | PDE Loss: 0.3754 | Boundary Loss: 0.8876 | Data Loss: 0.1733
# Total Loss: 4.5577 | PDE Loss: 0.3755 | Boundary Loss: 0.8861 | Data Loss: 0.1715
# Total Loss: 4.5263 | PDE Loss: 0.3764 | Boundary Loss: 0.8721 | Data Loss: 0.1563
# Total Loss: 4.2271 | PDE Loss: 0.3821 | Boundary Loss: 0.7341 | Data Loss: 0.0283
# Total Loss: 4.2203 | PDE Loss: 0.3823 | Boundary Loss: 0.7309 | Data Loss: 0.0256
# Total Loss: 4.1593 | PDE Loss: 0.3846 | Boundary Loss: 0.7019 | Data Loss: 0.0016
# Total Loss: 3.6368 | PDE Loss: 0.3982 | Boundary Loss: 0.4184 | Data Loss: -0.0948
# Total Loss: 3.6338 | PDE Loss: 0.3984 | Boundary Loss: 0.4167 | Data Loss: -0.0955
# Total Loss: 3.6202 | PDE Loss: 0.3990 | Boundary Loss: 0.4090 | Data Loss: -0.0987
# Total Loss: 3.4752 | PDE Loss: 0.4058 | Boundary Loss: 0.3234 | Data Loss: -0.1263
# Total Loss: 2.8861 | PDE Loss: 0.4373 | Boundary Loss: -0.3166 | Data Loss: -0.0396
# Total Loss: 2.8843 | PDE Loss: 0.4374 | Boundary Loss: -0.3180 | Data Loss: -0.0403
# Total Loss: 2.8766 | PDE Loss: 0.4377 | Boundary Loss: -0.3242 | Data Loss: -0.0437
# Total Loss: 2.7947 | PDE Loss: 0.4410 | Boundary Loss: -0.3949 | Data Loss: -0.0790
# Total Loss: 2.5045 | PDE Loss: 0.4626 | Boundary Loss: -0.9445 | Data Loss: -0.1571
# Total Loss: 2.5042 | PDE Loss: 0.4626 | Boundary Loss: -0.9446 | Data Loss: -0.1574
# Total Loss: 2.5027 | PDE Loss: 0.4625 | Boundary Loss: -0.9453 | Data Loss: -0.1583
# Total Loss: 2.4865 | PDE Loss: 0.4614 | Boundary Loss: -0.9517 | Data Loss: -0.1693
# Total Loss: 2.3356 | PDE Loss: 0.4505 | Boundary Loss: -0.9522 | Data Loss: -0.2873
# Total Loss: 2.3335 | PDE Loss: 0.4504 | Boundary Loss: -0.9526 | Data Loss: -0.2890
# Total Loss: 2.3147 | PDE Loss: 0.4492 | Boundary Loss: -0.9547 | Data Loss: -0.3045
# Total Loss: 2.1891 | PDE Loss: 0.4411 | Boundary Loss: -0.8307 | Data Loss: -0.4622
# Total Loss: 2.1889 | PDE Loss: 0.4411 | Boundary Loss: -0.8310 | Data Loss: -0.4623
# Total Loss: 2.1881 | PDE Loss: 0.4411 | Boundary Loss: -0.8323 | Data Loss: -0.4627
# Total Loss: 2.1789 | PDE Loss: 0.4414 | Boundary Loss: -0.8463 | Data Loss: -0.4673
# Total Loss: 2.1068 | PDE Loss: 0.4452 | Boundary Loss: -0.9451 | Data Loss: -0.5145
# Total Loss: 2.1062 | PDE Loss: 0.4451 | Boundary Loss: -0.9455 | Data Loss: -0.5150
# Total Loss: 2.1009 | PDE Loss: 0.4444 | Boundary Loss: -0.9493 | Data Loss: -0.5190
# Total Loss: 2.0537 | PDE Loss: 0.4366 | Boundary Loss: -0.9744 | Data Loss: -0.5589
# Total Loss: 2.0529 | PDE Loss: 0.4366 | Boundary Loss: -0.9758 | Data Loss: -0.5593
# Total Loss: 2.0493 | PDE Loss: 0.4363 | Boundary Loss: -0.9821 | Data Loss: -0.5610
# Total Loss: 2.0114 | PDE Loss: 0.4332 | Boundary Loss: -1.0505 | Data Loss: -0.5801
# Total Loss: 1.7940 | PDE Loss: 0.3952 | Boundary Loss: -1.3413 | Data Loss: -0.7386
# Total Loss: 1.7935 | PDE Loss: 0.3951 | Boundary Loss: -1.3433 | Data Loss: -0.7388
# Total Loss: 1.7887 | PDE Loss: 0.3946 | Boundary Loss: -1.3613 | Data Loss: -0.7407
# Total Loss: 1.7451 | PDE Loss: 0.3898 | Boundary Loss: -1.5607 | Data Loss: -0.7572
# Total Loss: 1.7448 | PDE Loss: 0.3897 | Boundary Loss: -1.5621 | Data Loss: -0.7574
# Total Loss: 1.7417 | PDE Loss: 0.3893 | Boundary Loss: -1.5746 | Data Loss: -0.7593
# Total Loss: 1.7119 | PDE Loss: 0.3853 | Boundary Loss: -1.7048 | Data Loss: -0.7789
# Total Loss: 1.5299 | PDE Loss: 0.3371 | Boundary Loss: -2.3049 | Data Loss: -0.9442
# Total Loss: 1.5294 | PDE Loss: 0.3370 | Boundary Loss: -2.3088 | Data Loss: -0.9447
# Total Loss: 1.5252 | PDE Loss: 0.3365 | Boundary Loss: -2.3440 | Data Loss: -0.9498
# Total Loss: 1.4871 | PDE Loss: 0.3319 | Boundary Loss: -2.7818 | Data Loss: -0.9990
# Total Loss: 1.4864 | PDE Loss: 0.3317 | Boundary Loss: -2.7856 | Data Loss: -0.9999
# Total Loss: 1.4796 | PDE Loss: 0.3297 | Boundary Loss: -2.8169 | Data Loss: -1.0083
# Total Loss: 1.4471 | PDE Loss: 0.3198 | Boundary Loss: -2.8684 | Data Loss: -1.0508
# Total Loss: 1.3826 | PDE Loss: 0.2483 | Boundary Loss: -1.3837 | Data Loss: -1.2711
# Total Loss: 1.3526 | PDE Loss: 0.2707 | Boundary Loss: -1.7929 | Data Loss: -1.2381
# Total Loss: 1.3522 | PDE Loss: 0.2707 | Boundary Loss: -1.7935 | Data Loss: -1.2389
# Total Loss: 1.3485 | PDE Loss: 0.2700 | Boundary Loss: -1.7991 | Data Loss: -1.2460
# Total Loss: 1.3143 | PDE Loss: 0.2637 | Boundary Loss: -1.8487 | Data Loss: -1.3174
# Total Loss: 1.3137 | PDE Loss: 0.2636 | Boundary Loss: -1.8501 | Data Loss: -1.3187
# Total Loss: 1.3081 | PDE Loss: 0.2627 | Boundary Loss: -1.8625 | Data Loss: -1.3305
# Total Loss: 1.2617 | PDE Loss: 0.2541 | Boundary Loss: -1.9736 | Data Loss: -1.4367
# Total Loss: 1.2614 | PDE Loss: 0.2541 | Boundary Loss: -1.9746 | Data Loss: -1.4375
# Total Loss: 1.2596 | PDE Loss: 0.2537 | Boundary Loss: -1.9795 | Data Loss: -1.4415
# Total Loss: 1.2506 | PDE Loss: 0.2516 | Boundary Loss: -2.0055 | Data Loss: -1.4628
# Total Loss: 1.1809 | PDE Loss: 0.2298 | Boundary Loss: -2.1962 | Data Loss: -1.6377
# Total Loss: 1.1809 | PDE Loss: 0.2297 | Boundary Loss: -2.1964 | Data Loss: -1.6378
# Total Loss: 1.1807 | PDE Loss: 0.2297 | Boundary Loss: -2.1967 | Data Loss: -1.6380
# Total Loss: 1.1798 | PDE Loss: 0.2292 | Boundary Loss: -2.1990 | Data Loss: -1.6392
# Total Loss: 1.1752 | PDE Loss: 0.2264 | Boundary Loss: -2.2113 | Data Loss: -1.6443
# Total Loss: 1.1751 | PDE Loss: 0.2263 | Boundary Loss: -2.2117 | Data Loss: -1.6443
# Total Loss: 1.1749 | PDE Loss: 0.2262 | Boundary Loss: -2.2133 | Data Loss: -1.6445
# Total Loss: 1.1734 | PDE Loss: 0.2254 | Boundary Loss: -2.2227 | Data Loss: -1.6454
# Total Loss: 1.1602 | PDE Loss: 0.2173 | Boundary Loss: -2.3182 | Data Loss: -1.6451
# Total Loss: 1.1602 | PDE Loss: 0.2172 | Boundary Loss: -2.3181 | Data Loss: -1.6452
# Total Loss: 1.1600 | PDE Loss: 0.2171 | Boundary Loss: -2.3178 | Data Loss: -1.6453
# Total Loss: 1.1585 | PDE Loss: 0.2159 | Boundary Loss: -2.3155 | Data Loss: -1.6464
# Total Loss: 1.1512 | PDE Loss: 0.2095 | Boundary Loss: -2.2988 | Data Loss: -1.6493
# Total Loss: 1.1511 | PDE Loss: 0.2094 | Boundary Loss: -2.2996 | Data Loss: -1.6492
# Total Loss: 1.1507 | PDE Loss: 0.2091 | Boundary Loss: -2.3031 | Data Loss: -1.6488
# Total Loss: 1.1465 | PDE Loss: 0.2060 | Boundary Loss: -2.3418 | Data Loss: -1.6440
# Total Loss: 1.1290 | PDE Loss: 0.1901 | Boundary Loss: -2.5455 | Data Loss: -1.6095
# Total Loss: 1.1289 | PDE Loss: 0.1900 | Boundary Loss: -2.5455 | Data Loss: -1.6095
# Total Loss: 1.1286 | PDE Loss: 0.1898 | Boundary Loss: -2.5448 | Data Loss: -1.6095
# Total Loss: 1.1269 | PDE Loss: 0.1881 | Boundary Loss: -2.5410 | Data Loss: -1.6094
# Total Loss: 1.1100 | PDE Loss: 0.1702 | Boundary Loss: -2.4653 | Data Loss: -1.6026
# Total Loss: 1.1098 | PDE Loss: 0.1700 | Boundary Loss: -2.4659 | Data Loss: -1.6025
# Total Loss: 1.1087 | PDE Loss: 0.1691 | Boundary Loss: -2.4681 | Data Loss: -1.6024
# Total Loss: 1.1028 | PDE Loss: 0.1638 | Boundary Loss: -2.4793 | Data Loss: -1.6017
# Total Loss: 1.0415 | PDE Loss: 0.1039 | Boundary Loss: -2.4173 | Data Loss: -1.6006
# Total Loss: 1.0405 | PDE Loss: 0.1030 | Boundary Loss: -2.4158 | Data Loss: -1.6011
# Total Loss: 1.0360 | PDE Loss: 0.0986 | Boundary Loss: -2.4081 | Data Loss: -1.6030
# Total Loss: 0.9883 | PDE Loss: 0.0497 | Boundary Loss: -2.2528 | Data Loss: -1.6324
# Total Loss: 0.9316 | PDE Loss: -0.1107 | Boundary Loss: -1.5072 | Data Loss: -1.7710
# Total Loss: 0.9313 | PDE Loss: -0.1109 | Boundary Loss: -1.5077 | Data Loss: -1.7711
# Total Loss: 0.9299 | PDE Loss: -0.1119 | Boundary Loss: -1.5100 | Data Loss: -1.7718
# Total Loss: 0.9148 | PDE Loss: -0.1221 | Boundary Loss: -1.5353 | Data Loss: -1.7786
# Total Loss: 0.7925 | PDE Loss: -0.2296 | Boundary Loss: -1.7851 | Data Loss: -1.7681
# Total Loss: 0.7915 | PDE Loss: -0.2303 | Boundary Loss: -1.7871 | Data Loss: -1.7691
# Total Loss: 0.7872 | PDE Loss: -0.2335 | Boundary Loss: -1.7962 | Data Loss: -1.7736
# Total Loss: 0.7414 | PDE Loss: -0.2697 | Boundary Loss: -1.8987 | Data Loss: -1.8239
# Total Loss: 0.5066 | PDE Loss: -0.6568 | Boundary Loss: -2.1255 | Data Loss: -2.1138
# Total Loss: 0.5062 | PDE Loss: -0.6575 | Boundary Loss: -2.1273 | Data Loss: -2.1139
# Total Loss: 0.5033 | PDE Loss: -0.6627 | Boundary Loss: -2.1400 | Data Loss: -2.1141
# Total Loss: 0.4769 | PDE Loss: -0.7174 | Boundary Loss: -2.2717 | Data Loss: -2.1077
# Total Loss: 0.4767 | PDE Loss: -0.7178 | Boundary Loss: -2.2735 | Data Loss: -2.1077
# Total Loss: 0.4751 | PDE Loss: -0.7204 | Boundary Loss: -2.2855 | Data Loss: -2.1076
# Total Loss: 0.4672 | PDE Loss: -0.7336 | Boundary Loss: -2.3501 | Data Loss: -2.1070
# Total Loss: 0.4316 | PDE Loss: -0.8088 | Boundary Loss: -2.8248 | Data Loss: -2.0913
# Total Loss: 0.4312 | PDE Loss: -0.8100 | Boundary Loss: -2.8248 | Data Loss: -2.0920
# Total Loss: 0.4296 | PDE Loss: -0.8155 | Boundary Loss: -2.8248 | Data Loss: -2.0953
# Total Loss: 0.4139 | PDE Loss: -0.8766 | Boundary Loss: -2.7981 | Data Loss: -2.1266
# Total Loss: 0.4138 | PDE Loss: -0.8771 | Boundary Loss: -2.7990 | Data Loss: -2.1267
# Total Loss: 0.4131 | PDE Loss: -0.8794 | Boundary Loss: -2.8025 | Data Loss: -2.1275
# Total Loss: 0.4098 | PDE Loss: -0.8920 | Boundary Loss: -2.8225 | Data Loss: -2.1315
# Total Loss: 0.3793 | PDE Loss: -1.0342 | Boundary Loss: -2.9797 | Data Loss: -2.1675
# Total Loss: 0.3793 | PDE Loss: -1.0346 | Boundary Loss: -2.9803 | Data Loss: -2.1676
# Total Loss: 0.3792 | PDE Loss: -1.0351 | Boundary Loss: -2.9807 | Data Loss: -2.1678
# Total Loss: 0.3785 | PDE Loss: -1.0388 | Boundary Loss: -2.9842 | Data Loss: -2.1689
# Total Loss: 0.3747 | PDE Loss: -1.0596 | Boundary Loss: -3.0027 | Data Loss: -2.1748
# Total Loss: 0.3484 | PDE Loss: -1.2775 | Boundary Loss: -3.0862 | Data Loss: -2.1975
# Total Loss: 0.3484 | PDE Loss: -1.2776 | Boundary Loss: -3.0865 | Data Loss: -2.1976
# Total Loss: 0.3483 | PDE Loss: -1.2778 | Boundary Loss: -3.0865 | Data Loss: -2.1977
# Total Loss: 0.3481 | PDE Loss: -1.2792 | Boundary Loss: -3.0877 | Data Loss: -2.1985
# Total Loss: 0.3459 | PDE Loss: -1.2949 | Boundary Loss: -3.0993 | Data Loss: -2.2063
# Total Loss: 0.3459 | PDE Loss: -1.2951 | Boundary Loss: -3.1000 | Data Loss: -2.2064
# Total Loss: 0.3458 | PDE Loss: -1.2954 | Boundary Loss: -3.1007 | Data Loss: -2.2065
# Total Loss: 0.3455 | PDE Loss: -1.2974 | Boundary Loss: -3.1063 | Data Loss: -2.2074
# Total Loss: 0.3438 | PDE Loss: -1.3083 | Boundary Loss: -3.1378 | Data Loss: -2.2120
# Total Loss: 0.3333 | PDE Loss: -1.3869 | Boundary Loss: -3.3606 | Data Loss: -2.2415
# Total Loss: 0.3333 | PDE Loss: -1.3870 | Boundary Loss: -3.3606 | Data Loss: -2.2417
# Total Loss: 0.3333 | PDE Loss: -1.3872 | Boundary Loss: -3.3605 | Data Loss: -2.2419
# Total Loss: 0.3330 | PDE Loss: -1.3888 | Boundary Loss: -3.3604 | Data Loss: -2.2433
# Total Loss: 0.3318 | PDE Loss: -1.3967 | Boundary Loss: -3.3583 | Data Loss: -2.2511
# Total Loss: 0.3262 | PDE Loss: -1.4368 | Boundary Loss: -3.3110 | Data Loss: -2.2920
# Total Loss: 0.3261 | PDE Loss: -1.4369 | Boundary Loss: -3.3116 | Data Loss: -2.2922
# Total Loss: 0.3261 | PDE Loss: -1.4371 | Boundary Loss: -3.3124 | Data Loss: -2.2924
# Total Loss: 0.3259 | PDE Loss: -1.4382 | Boundary Loss: -3.3179 | Data Loss: -2.2938
# Total Loss: 0.3240 | PDE Loss: -1.4480 | Boundary Loss: -3.3637 | Data Loss: -2.3062
# Total Loss: 0.3164 | PDE Loss: -1.4865 | Boundary Loss: -3.5005 | Data Loss: -2.3672
# Total Loss: 0.3164 | PDE Loss: -1.4866 | Boundary Loss: -3.5002 | Data Loss: -2.3674
# Total Loss: 0.3163 | PDE Loss: -1.4870 | Boundary Loss: -3.4988 | Data Loss: -2.3684
# Total Loss: 0.3159 | PDE Loss: -1.4890 | Boundary Loss: -3.4922 | Data Loss: -2.3736
# Total Loss: 0.3135 | PDE Loss: -1.5003 | Boundary Loss: -3.4397 | Data Loss: -2.4048
# Total Loss: 0.3134 | PDE Loss: -1.5004 | Boundary Loss: -3.4405 | Data Loss: -2.4052
# Total Loss: 0.3133 | PDE Loss: -1.5010 | Boundary Loss: -3.4440 | Data Loss: -2.4070
# Total Loss: 0.3115 | PDE Loss: -1.5069 | Boundary Loss: -3.4783 | Data Loss: -2.4267
# Total Loss: 0.2992 | PDE Loss: -1.5527 | Boundary Loss: -3.3684 | Data Loss: -2.6367
# Total Loss: 0.2992 | PDE Loss: -1.5528 | Boundary Loss: -3.3687 | Data Loss: -2.6370
# Total Loss: 0.2992 | PDE Loss: -1.5529 | Boundary Loss: -3.3689 | Data Loss: -2.6374
# Total Loss: 0.2990 | PDE Loss: -1.5539 | Boundary Loss: -3.3705 | Data Loss: -2.6404
# Total Loss: 0.2981 | PDE Loss: -1.5589 | Boundary Loss: -3.3782 | Data Loss: -2.6572
# Total Loss: 0.2902 | PDE Loss: -1.6137 | Boundary Loss: -3.2870 | Data Loss: -2.8476
# Total Loss: 0.2902 | PDE Loss: -1.6138 | Boundary Loss: -3.2880 | Data Loss: -2.8479
# Total Loss: 0.2902 | PDE Loss: -1.6140 | Boundary Loss: -3.2895 | Data Loss: -2.8485
# Total Loss: 0.2899 | PDE Loss: -1.6156 | Boundary Loss: -3.3014 | Data Loss: -2.8527
# Total Loss: 0.2882 | PDE Loss: -1.6253 | Boundary Loss: -3.3791 | Data Loss: -2.8792
# Total Loss: 0.2813 | PDE Loss: -1.6721 | Boundary Loss: -3.9021 | Data Loss: -3.0018
# Total Loss: 0.2813 | PDE Loss: -1.6722 | Boundary Loss: -3.9024 | Data Loss: -3.0020
# Total Loss: 0.2813 | PDE Loss: -1.6726 | Boundary Loss: -3.9029 | Data Loss: -3.0027
# Total Loss: 0.2811 | PDE Loss: -1.6749 | Boundary Loss: -3.9076 | Data Loss: -3.0066
# Total Loss: 0.2801 | PDE Loss: -1.6871 | Boundary Loss: -3.9299 | Data Loss: -3.0267
# Total Loss: 0.2801 | PDE Loss: -1.6872 | Boundary Loss: -3.9304 | Data Loss: -3.0269
# Total Loss: 0.2801 | PDE Loss: -1.6878 | Boundary Loss: -3.9341 | Data Loss: -3.0275
# Total Loss: 0.2798 | PDE Loss: -1.6912 | Boundary Loss: -3.9542 | Data Loss: -3.0310
# Total Loss: 0.2780 | PDE Loss: -1.7171 | Boundary Loss: -4.1228 | Data Loss: -3.0534
# Total Loss: 0.2780 | PDE Loss: -1.7172 | Boundary Loss: -4.1236 | Data Loss: -3.0535
# Total Loss: 0.2780 | PDE Loss: -1.7173 | Boundary Loss: -4.1240 | Data Loss: -3.0536
# Total Loss: 0.2780 | PDE Loss: -1.7183 | Boundary Loss: -4.1260 | Data Loss: -3.0544
# Total Loss: 0.2776 | PDE Loss: -1.7238 | Boundary Loss: -4.1404 | Data Loss: -3.0585
# Total Loss: 0.2759 | PDE Loss: -1.7580 | Boundary Loss: -4.1568 | Data Loss: -3.0753
# Total Loss: 0.2759 | PDE Loss: -1.7581 | Boundary Loss: -4.1577 | Data Loss: -3.0753
# Total Loss: 0.2759 | PDE Loss: -1.7582 | Boundary Loss: -4.1579 | Data Loss: -3.0753
# Total Loss: 0.2758 | PDE Loss: -1.7591 | Boundary Loss: -4.1644 | Data Loss: -3.0752
# Total Loss: 0.2756 | PDE Loss: -1.7638 | Boundary Loss: -4.1996 | Data Loss: -3.0747
# Total Loss: 0.2742 | PDE Loss: -1.7939 | Boundary Loss: -4.4468 | Data Loss: -3.0641
# Total Loss: 0.2742 | PDE Loss: -1.7940 | Boundary Loss: -4.4472 | Data Loss: -3.0641
# Total Loss: 0.2742 | PDE Loss: -1.7941 | Boundary Loss: -4.4467 | Data Loss: -3.0641
# Total Loss: 0.2742 | PDE Loss: -1.7946 | Boundary Loss: -4.4466 | Data Loss: -3.0640
# Total Loss: 0.2740 | PDE Loss: -1.7975 | Boundary Loss: -4.4442 | Data Loss: -3.0636
# Total Loss: 0.2735 | PDE Loss: -1.8131 | Boundary Loss: -4.4029 | Data Loss: -3.0605
# Total Loss: 0.2735 | PDE Loss: -1.8132 | Boundary Loss: -4.4044 | Data Loss: -3.0605
# Total Loss: 0.2735 | PDE Loss: -1.8132 | Boundary Loss: -4.4038 | Data Loss: -3.0605
# Total Loss: 0.2734 | PDE Loss: -1.8140 | Boundary Loss: -4.4089 | Data Loss: -3.0603
# Total Loss: 0.2734 | PDE Loss: -1.8157 | Boundary Loss: -4.4180 | Data Loss: -3.0600
# Total Loss: 0.2728 | PDE Loss: -1.8300 | Boundary Loss: -4.4826 | Data Loss: -3.0571
# Total Loss: 0.2728 | PDE Loss: -1.8302 | Boundary Loss: -4.4824 | Data Loss: -3.0572
# Total Loss: 0.2727 | PDE Loss: -1.8308 | Boundary Loss: -4.4832 | Data Loss: -3.0572
# Total Loss: 0.2726 | PDE Loss: -1.8333 | Boundary Loss: -4.4830 | Data Loss: -3.0573
# Total Loss: 0.2721 | PDE Loss: -1.8475 | Boundary Loss: -4.4656 | Data Loss: -3.0582
# Total Loss: 0.2702 | PDE Loss: -1.9316 | Boundary Loss: -3.6846 | Data Loss: -3.0504
# Total Loss: 0.2702 | PDE Loss: -1.9317 | Boundary Loss: -3.6850 | Data Loss: -3.0505
# Total Loss: 0.2702 | PDE Loss: -1.9318 | Boundary Loss: -3.6880 | Data Loss: -3.0508
# Total Loss: 0.2701 | PDE Loss: -1.9321 | Boundary Loss: -3.6930 | Data Loss: -3.0513
# Total Loss: 0.2699 | PDE Loss: -1.9340 | Boundary Loss: -3.7327 | Data Loss: -3.0550
# Total Loss: 0.2677 | PDE Loss: -1.9533 | Boundary Loss: -4.2714 | Data Loss: -3.0832
# Total Loss: 0.2677 | PDE Loss: -1.9534 | Boundary Loss: -4.2718 | Data Loss: -3.0833
# Total Loss: 0.2677 | PDE Loss: -1.9536 | Boundary Loss: -4.2717 | Data Loss: -3.0835
# Total Loss: 0.2677 | PDE Loss: -1.9554 | Boundary Loss: -4.2745 | Data Loss: -3.0847
# Total Loss: 0.2672 | PDE Loss: -1.9648 | Boundary Loss: -4.2819 | Data Loss: -3.0916
# Total Loss: 0.2642 | PDE Loss: -2.0625 | Boundary Loss: -3.7200 | Data Loss: -3.1763
# Total Loss: 0.2642 | PDE Loss: -2.0627 | Boundary Loss: -3.7207 | Data Loss: -3.1765
# Total Loss: 0.2642 | PDE Loss: -2.0630 | Boundary Loss: -3.7214 | Data Loss: -3.1768
# Total Loss: 0.2641 | PDE Loss: -2.0651 | Boundary Loss: -3.7272 | Data Loss: -3.1791
# Total Loss: 0.2637 | PDE Loss: -2.0767 | Boundary Loss: -3.7585 | Data Loss: -3.1915
# Total Loss: 0.2600 | PDE Loss: -2.2054 | Boundary Loss: -3.8677 | Data Loss: -3.3156
# Total Loss: 0.2600 | PDE Loss: -2.2055 | Boundary Loss: -3.8684 | Data Loss: -3.3157
# Total Loss: 0.2600 | PDE Loss: -2.2056 | Boundary Loss: -3.8684 | Data Loss: -3.3158
# Total Loss: 0.2599 | PDE Loss: -2.2069 | Boundary Loss: -3.8707 | Data Loss: -3.3171
# Total Loss: 0.2597 | PDE Loss: -2.2125 | Boundary Loss: -3.8807 | Data Loss: -3.3227
# Total Loss: 0.2581 | PDE Loss: -2.2732 | Boundary Loss: -3.9369 | Data Loss: -3.3784
# Total Loss: 0.2581 | PDE Loss: -2.2734 | Boundary Loss: -3.9383 | Data Loss: -3.3785
# Total Loss: 0.2581 | PDE Loss: -2.2744 | Boundary Loss: -3.9450 | Data Loss: -3.3791
# Total Loss: 0.2579 | PDE Loss: -2.2798 | Boundary Loss: -3.9838 | Data Loss: -3.3817
# Total Loss: 0.2573 | PDE Loss: -2.3023 | Boundary Loss: -4.1606 | Data Loss: -3.3894
# Total Loss: 0.2573 | PDE Loss: -2.3026 | Boundary Loss: -4.1607 | Data Loss: -3.3897
# Total Loss: 0.2573 | PDE Loss: -2.3029 | Boundary Loss: -4.1602 | Data Loss: -3.3900
# Total Loss: 0.2573 | PDE Loss: -2.3042 | Boundary Loss: -4.1585 | Data Loss: -3.3912
# Total Loss: 0.2571 | PDE Loss: -2.3129 | Boundary Loss: -4.1467 | Data Loss: -3.3995
# Total Loss: 0.2563 | PDE Loss: -2.3568 | Boundary Loss: -4.0482 | Data Loss: -3.4427
# Total Loss: 0.2563 | PDE Loss: -2.3569 | Boundary Loss: -4.0485 | Data Loss: -3.4428
# Total Loss: 0.2563 | PDE Loss: -2.3573 | Boundary Loss: -4.0494 | Data Loss: -3.4430
# Total Loss: 0.2563 | PDE Loss: -2.3578 | Boundary Loss: -4.0509 | Data Loss: -3.4433
# Total Loss: 0.2562 | PDE Loss: -2.3625 | Boundary Loss: -4.0628 | Data Loss: -3.4458
# Total Loss: 0.2558 | PDE Loss: -2.3862 | Boundary Loss: -4.1237 | Data Loss: -3.4566
# Total Loss: 0.2558 | PDE Loss: -2.3863 | Boundary Loss: -4.1238 | Data Loss: -3.4566
# Total Loss: 0.2557 | PDE Loss: -2.3867 | Boundary Loss: -4.1246 | Data Loss: -3.4568
# Total Loss: 0.2557 | PDE Loss: -2.3890 | Boundary Loss: -4.1300 | Data Loss: -3.4577
# Total Loss: 0.2555 | PDE Loss: -2.3978 | Boundary Loss: -4.1499 | Data Loss: -3.4610
# Total Loss: 0.2555 | PDE Loss: -2.3979 | Boundary Loss: -4.1500 | Data Loss: -3.4610
# Total Loss: 0.2555 | PDE Loss: -2.3983 | Boundary Loss: -4.1510 | Data Loss: -3.4611
# Total Loss: 0.2555 | PDE Loss: -2.4003 | Boundary Loss: -4.1566 | Data Loss: -3.4617
# Total Loss: 0.2553 | PDE Loss: -2.4119 | Boundary Loss: -4.1898 | Data Loss: -3.4640
# Total Loss: 0.2553 | PDE Loss: -2.4120 | Boundary Loss: -4.1896 | Data Loss: -3.4641
# Total Loss: 0.2553 | PDE Loss: -2.4122 | Boundary Loss: -4.1909 | Data Loss: -3.4641
# Total Loss: 0.2553 | PDE Loss: -2.4124 | Boundary Loss: -4.1917 | Data Loss: -3.4641
# Total Loss: 0.2553 | PDE Loss: -2.4128 | Boundary Loss: -4.1926 | Data Loss: -3.4642
# Total Loss: 0.2552 | PDE Loss: -2.4168 | Boundary Loss: -4.2048 | Data Loss: -3.4645
# Total Loss: 0.2549 | PDE Loss: -2.4341 | Boundary Loss: -4.2581 | Data Loss: -3.4619
# Total Loss: 0.2549 | PDE Loss: -2.4341 | Boundary Loss: -4.2577 | Data Loss: -3.4619
# Total Loss: 0.2549 | PDE Loss: -2.4341 | Boundary Loss: -4.2579 | Data Loss: -3.4619
# Total Loss: 0.2549 | PDE Loss: -2.4341 | Boundary Loss: -4.2579 | Data Loss: -3.4619
# Total Loss: 0.2549 | PDE Loss: -2.4342 | Boundary Loss: -4.2593 | Data Loss: -3.4618
# Total Loss: 0.2549 | PDE Loss: -2.4342 | Boundary Loss: -4.2595 | Data Loss: -3.4617
# Total Loss: 0.2549 | PDE Loss: -2.4347 | Boundary Loss: -4.2685 | Data Loss: -3.4609
# Total Loss: 0.2548 | PDE Loss: -2.4355 | Boundary Loss: -4.2839 | Data Loss: -3.4594
# Total Loss: 0.2547 | PDE Loss: -2.4411 | Boundary Loss: -4.4109 | Data Loss: -3.4464
# Total Loss: 0.2547 | PDE Loss: -2.4411 | Boundary Loss: -4.4112 | Data Loss: -3.4463
# Total Loss: 0.2547 | PDE Loss: -2.4412 | Boundary Loss: -4.4116 | Data Loss: -3.4463
# Total Loss: 0.2547 | PDE Loss: -2.4412 | Boundary Loss: -4.4118 | Data Loss: -3.4463
# Total Loss: 0.2547 | PDE Loss: -2.4417 | Boundary Loss: -4.4156 | Data Loss: -3.4457
# Total Loss: 0.2547 | PDE Loss: -2.4431 | Boundary Loss: -4.4253 | Data Loss: -3.4440
# Total Loss: 0.2547 | PDE Loss: -2.4431 | Boundary Loss: -4.4256 | Data Loss: -3.4440
# Total Loss: 0.2547 | PDE Loss: -2.4431 | Boundary Loss: -4.4258 | Data Loss: -3.4440
# Total Loss: 0.2547 | PDE Loss: -2.4431 | Boundary Loss: -4.4258 | Data Loss: -3.4440
# Total Loss: 0.2547 | PDE Loss: -2.4431 | Boundary Loss: -4.4258 | Data Loss: -3.4440
# Total Loss: 0.2547 | PDE Loss: -2.4431 | Boundary Loss: -4.4258 | Data Loss: -3.4440
# Total Loss: 0.2547 | PDE Loss: -2.4432 | Boundary Loss: -4.4255 | Data Loss: -3.4440
# Total Loss: 0.2547 | PDE Loss: -2.4433 | Boundary Loss: -4.4243 | Data Loss: -3.4441
# Total Loss: 0.2547 | PDE Loss: -2.4434 | Boundary Loss: -4.4224 | Data Loss: -3.4442
# Total Loss: 0.2547 | PDE Loss: -2.4440 | Boundary Loss: -4.4166 | Data Loss: -3.4446
# Total Loss: 0.2546 | PDE Loss: -2.4469 | Boundary Loss: -4.3688 | Data Loss: -3.4470
# Total Loss: 0.2546 | PDE Loss: -2.4469 | Boundary Loss: -4.3686 | Data Loss: -3.4470
# Total Loss: 0.2546 | PDE Loss: -2.4469 | Boundary Loss: -4.3685 | Data Loss: -3.4470
# Total Loss: 0.2545 | PDE Loss: -2.4475 | Boundary Loss: -4.3645 | Data Loss: -3.4468
# Total Loss: 0.2545 | PDE Loss: -2.4496 | Boundary Loss: -4.3402 | Data Loss: -3.4459
# Total Loss: 0.2545 | PDE Loss: -2.4496 | Boundary Loss: -4.3398 | Data Loss: -3.4459
# Total Loss: 0.2545 | PDE Loss: -2.4496 | Boundary Loss: -4.3398 | Data Loss: -3.4459
# Total Loss: 0.2545 | PDE Loss: -2.4496 | Boundary Loss: -4.3398 | Data Loss: -3.4459
# Total Loss: 0.2545 | PDE Loss: -2.4496 | Boundary Loss: -4.3398 | Data Loss: -3.4459
# Total Loss: 0.2545 | PDE Loss: -2.4496 | Boundary Loss: -4.3404 | Data Loss: -3.4459
# Total Loss: 0.2544 | PDE Loss: -2.4497 | Boundary Loss: -4.3405 | Data Loss: -3.4458
# Total Loss: 0.2544 | PDE Loss: -2.4498 | Boundary Loss: -4.3433 | Data Loss: -3.4454
# Total Loss: 0.2544 | PDE Loss: -2.4504 | Boundary Loss: -4.3595 | Data Loss: -3.4429
# Total Loss: 0.2543 | PDE Loss: -2.4513 | Boundary Loss: -4.3996 | Data Loss: -3.4352
# Total Loss: 0.2543 | PDE Loss: -2.4513 | Boundary Loss: -4.3990 | Data Loss: -3.4352
# Total Loss: 0.2543 | PDE Loss: -2.4514 | Boundary Loss: -4.4001 | Data Loss: -3.4352
# Total Loss: 0.2543 | PDE Loss: -2.4514 | Boundary Loss: -4.4000 | Data Loss: -3.4351
# Total Loss: 0.2543 | PDE Loss: -2.4518 | Boundary Loss: -4.4034 | Data Loss: -3.4345
# Total Loss: 0.2542 | PDE Loss: -2.4525 | Boundary Loss: -4.4089 | Data Loss: -3.4329
# Total Loss: 0.2540 | PDE Loss: -2.4518 | Boundary Loss: -4.3980 | Data Loss: -3.4204
# Total Loss: 0.2540 | PDE Loss: -2.4519 | Boundary Loss: -4.3983 | Data Loss: -3.4205
# Total Loss: 0.2540 | PDE Loss: -2.4519 | Boundary Loss: -4.3982 | Data Loss: -3.4205
# Total Loss: 0.2540 | PDE Loss: -2.4519 | Boundary Loss: -4.3982 | Data Loss: -3.4206
# Total Loss: 0.2540 | PDE Loss: -2.4522 | Boundary Loss: -4.3968 | Data Loss: -3.4213
# Total Loss: 0.2539 | PDE Loss: -2.4537 | Boundary Loss: -4.3915 | Data Loss: -3.4254
# Total Loss: 0.2536 | PDE Loss: -2.4597 | Boundary Loss: -4.3574 | Data Loss: -3.4443
# Total Loss: 0.2536 | PDE Loss: -2.4599 | Boundary Loss: -4.3581 | Data Loss: -3.4446
# Total Loss: 0.2536 | PDE Loss: -2.4600 | Boundary Loss: -4.3578 | Data Loss: -3.4449
# Total Loss: 0.2535 | PDE Loss: -2.4612 | Boundary Loss: -4.3578 | Data Loss: -3.4475
# Total Loss: 0.2533 | PDE Loss: -2.4674 | Boundary Loss: -4.3586 | Data Loss: -3.4617
# Total Loss: 0.2514 | PDE Loss: -2.5097 | Boundary Loss: -4.2524 | Data Loss: -3.6094
# Total Loss: 0.2514 | PDE Loss: -2.5099 | Boundary Loss: -4.2526 | Data Loss: -3.6098
# Total Loss: 0.2514 | PDE Loss: -2.5105 | Boundary Loss: -4.2543 | Data Loss: -3.6113
# Total Loss: 0.2513 | PDE Loss: -2.5160 | Boundary Loss: -4.2672 | Data Loss: -3.6238
# Total Loss: 0.2505 | PDE Loss: -2.5413 | Boundary Loss: -4.3357 | Data Loss: -3.6844
# Total Loss: 0.2505 | PDE Loss: -2.5415 | Boundary Loss: -4.3378 | Data Loss: -3.6849
# Total Loss: 0.2505 | PDE Loss: -2.5417 | Boundary Loss: -4.3378 | Data Loss: -3.6852
# Total Loss: 0.2504 | PDE Loss: -2.5434 | Boundary Loss: -4.3432 | Data Loss: -3.6886
# Total Loss: 0.2502 | PDE Loss: -2.5530 | Boundary Loss: -4.3747 | Data Loss: -3.7078
# Total Loss: 0.2490 | PDE Loss: -2.5979 | Boundary Loss: -4.5787 | Data Loss: -3.7963
# Total Loss: 0.2490 | PDE Loss: -2.5982 | Boundary Loss: -4.5793 | Data Loss: -3.7967
# Total Loss: 0.2490 | PDE Loss: -2.5991 | Boundary Loss: -4.5834 | Data Loss: -3.7983
# Total Loss: 0.2489 | PDE Loss: -2.6026 | Boundary Loss: -4.5981 | Data Loss: -3.8042
# Total Loss: 0.2481 | PDE Loss: -2.6382 | Boundary Loss: -4.7772 | Data Loss: -3.8603
# Total Loss: 0.2481 | PDE Loss: -2.6384 | Boundary Loss: -4.7777 | Data Loss: -3.8606
# Total Loss: 0.2480 | PDE Loss: -2.6393 | Boundary Loss: -4.7818 | Data Loss: -3.8620
# Total Loss: 0.2480 | PDE Loss: -2.6435 | Boundary Loss: -4.7993 | Data Loss: -3.8680
# Total Loss: 0.2475 | PDE Loss: -2.6651 | Boundary Loss: -4.9007 | Data Loss: -3.8959
# Total Loss: 0.2475 | PDE Loss: -2.6653 | Boundary Loss: -4.9020 | Data Loss: -3.8961
# Total Loss: 0.2475 | PDE Loss: -2.6661 | Boundary Loss: -4.9053 | Data Loss: -3.8969
# Total Loss: 0.2474 | PDE Loss: -2.6694 | Boundary Loss: -4.9192 | Data Loss: -3.9003
# Total Loss: 0.2471 | PDE Loss: -2.6880 | Boundary Loss: -5.0067 | Data Loss: -3.9171
# Total Loss: 0.2449 | PDE Loss: -2.7437 | Boundary Loss: -5.1385 | Data Loss: -3.7999
# Total Loss: 0.2449 | PDE Loss: -2.7436 | Boundary Loss: -5.1399 | Data Loss: -3.7997
# Total Loss: 0.2449 | PDE Loss: -2.7433 | Boundary Loss: -5.1539 | Data Loss: -3.7988
# Total Loss: 0.2449 | PDE Loss: -2.7426 | Boundary Loss: -5.1791 | Data Loss: -3.7972
# Total Loss: 0.2449 | PDE Loss: -2.7377 | Boundary Loss: -5.3653 | Data Loss: -3.7844
# Total Loss: 0.2449 | PDE Loss: -2.7377 | Boundary Loss: -5.3659 | Data Loss: -3.7842
# Total Loss: 0.2449 | PDE Loss: -2.7377 | Boundary Loss: -5.3715 | Data Loss: -3.7837
# Total Loss: 0.2448 | PDE Loss: -2.7379 | Boundary Loss: -5.3860 | Data Loss: -3.7822
# Total Loss: 0.2447 | PDE Loss: -2.7383 | Boundary Loss: -5.4818 | Data Loss: -3.7721
# Total Loss: 0.2441 | PDE Loss: -2.6980 | Boundary Loss: -5.6786 | Data Loss: -3.6212
# Total Loss: 0.2441 | PDE Loss: -2.6980 | Boundary Loss: -5.6810 | Data Loss: -3.6212
# Total Loss: 0.2441 | PDE Loss: -2.6980 | Boundary Loss: -5.6844 | Data Loss: -3.6211
# Total Loss: 0.2441 | PDE Loss: -2.6980 | Boundary Loss: -5.6870 | Data Loss: -3.6209
# Total Loss: 0.2441 | PDE Loss: -2.6979 | Boundary Loss: -5.6928 | Data Loss: -3.6206
# Total Loss: 0.2441 | PDE Loss: -2.6976 | Boundary Loss: -5.7478 | Data Loss: -3.6180
# Total Loss: 0.2439 | PDE Loss: -2.6949 | Boundary Loss: -5.9027 | Data Loss: -3.6063
# Total Loss: 0.2439 | PDE Loss: -2.6949 | Boundary Loss: -5.9028 | Data Loss: -3.6062
# Total Loss: 0.2439 | PDE Loss: -2.6949 | Boundary Loss: -5.9015 | Data Loss: -3.6060
# Total Loss: 0.2439 | PDE Loss: -2.6949 | Boundary Loss: -5.9002 | Data Loss: -3.6050
# Total Loss: 0.2437 | PDE Loss: -2.6936 | Boundary Loss: -5.8146 | Data Loss: -3.5926
# Total Loss: 0.2430 | PDE Loss: -2.6701 | Boundary Loss: -5.0258 | Data Loss: -3.5270
# Total Loss: 0.2430 | PDE Loss: -2.6702 | Boundary Loss: -5.0266 | Data Loss: -3.5270
# Total Loss: 0.2430 | PDE Loss: -2.6702 | Boundary Loss: -5.0266 | Data Loss: -3.5269
# Total Loss: 0.2429 | PDE Loss: -2.6706 | Boundary Loss: -5.0264 | Data Loss: -3.5265
# Total Loss: 0.2422 | PDE Loss: -2.6657 | Boundary Loss: -4.8108 | Data Loss: -3.5169
# Total Loss: 0.2422 | PDE Loss: -2.6657 | Boundary Loss: -4.8113 | Data Loss: -3.5170
# Total Loss: 0.2422 | PDE Loss: -2.6657 | Boundary Loss: -4.8118 | Data Loss: -3.5171
# Total Loss: 0.2422 | PDE Loss: -2.6658 | Boundary Loss: -4.8139 | Data Loss: -3.5180
# Total Loss: 0.2420 | PDE Loss: -2.6657 | Boundary Loss: -4.8207 | Data Loss: -3.5230
# Total Loss: 0.2412 | PDE Loss: -2.6536 | Boundary Loss: -4.6548 | Data Loss: -3.5437
# Total Loss: 0.2412 | PDE Loss: -2.6535 | Boundary Loss: -4.6569 | Data Loss: -3.5440
# Total Loss: 0.2412 | PDE Loss: -2.6535 | Boundary Loss: -4.6560 | Data Loss: -3.5442
# Total Loss: 0.2412 | PDE Loss: -2.6534 | Boundary Loss: -4.6650 | Data Loss: -3.5462
# Total Loss: 0.2410 | PDE Loss: -2.6524 | Boundary Loss: -4.7099 | Data Loss: -3.5569
# Total Loss: 0.2405 | PDE Loss: -2.6386 | Boundary Loss: -4.8586 | Data Loss: -3.6117
# Total Loss: 0.2405 | PDE Loss: -2.6384 | Boundary Loss: -4.8575 | Data Loss: -3.6119
# Total Loss: 0.2404 | PDE Loss: -2.6373 | Boundary Loss: -4.8551 | Data Loss: -3.6130
# Total Loss: 0.2403 | PDE Loss: -2.6341 | Boundary Loss: -4.8390 | Data Loss: -3.6159
# Total Loss: 0.2400 | PDE Loss: -2.6132 | Boundary Loss: -4.5208 | Data Loss: -3.6268
# Total Loss: 0.2400 | PDE Loss: -2.6131 | Boundary Loss: -4.5212 | Data Loss: -3.6271
# Total Loss: 0.2400 | PDE Loss: -2.6131 | Boundary Loss: -4.5218 | Data Loss: -3.6272
# Total Loss: 0.2400 | PDE Loss: -2.6130 | Boundary Loss: -4.5213 | Data Loss: -3.6273
# Total Loss: 0.2400 | PDE Loss: -2.6126 | Boundary Loss: -4.5256 | Data Loss: -3.6294
# Total Loss: 0.2399 | PDE Loss: -2.6113 | Boundary Loss: -4.5352 | Data Loss: -3.6349
# Total Loss: 0.2396 | PDE Loss: -2.6015 | Boundary Loss: -4.5900 | Data Loss: -3.6701
# Total Loss: 0.2396 | PDE Loss: -2.6015 | Boundary Loss: -4.5904 | Data Loss: -3.6703
# Total Loss: 0.2396 | PDE Loss: -2.6014 | Boundary Loss: -4.5938 | Data Loss: -3.6715
# Total Loss: 0.2396 | PDE Loss: -2.6008 | Boundary Loss: -4.6145 | Data Loss: -3.6778
# Total Loss: 0.2391 | PDE Loss: -2.5910 | Boundary Loss: -4.8513 | Data Loss: -3.7437
# Total Loss: 0.2391 | PDE Loss: -2.5910 | Boundary Loss: -4.8512 | Data Loss: -3.7439
# Total Loss: 0.2391 | PDE Loss: -2.5908 | Boundary Loss: -4.8528 | Data Loss: -3.7448
# Total Loss: 0.2391 | PDE Loss: -2.5904 | Boundary Loss: -4.8576 | Data Loss: -3.7476
# Total Loss: 0.2390 | PDE Loss: -2.5875 | Boundary Loss: -4.8881 | Data Loss: -3.7644
# Total Loss: 0.2384 | PDE Loss: -2.5607 | Boundary Loss: -4.8269 | Data Loss: -3.8424
# Total Loss: 0.2384 | PDE Loss: -2.5607 | Boundary Loss: -4.8273 | Data Loss: -3.8425
# Total Loss: 0.2384 | PDE Loss: -2.5606 | Boundary Loss: -4.8310 | Data Loss: -3.8431
# Total Loss: 0.2384 | PDE Loss: -2.5604 | Boundary Loss: -4.8406 | Data Loss: -3.8443
# Total Loss: 0.2384 | PDE Loss: -2.5596 | Boundary Loss: -4.8733 | Data Loss: -3.8486
# Total Loss: 0.2383 | PDE Loss: -2.5538 | Boundary Loss: -5.1092 | Data Loss: -3.8729
# Total Loss: 0.2383 | PDE Loss: -2.5538 | Boundary Loss: -5.1081 | Data Loss: -3.8729
# Total Loss: 0.2383 | PDE Loss: -2.5536 | Boundary Loss: -5.1077 | Data Loss: -3.8731
# Total Loss: 0.2383 | PDE Loss: -2.5535 | Boundary Loss: -5.1068 | Data Loss: -3.8733
# Total Loss: 0.2383 | PDE Loss: -2.5532 | Boundary Loss: -5.1064 | Data Loss: -3.8736
# Total Loss: 0.2383 | PDE Loss: -2.5526 | Boundary Loss: -5.1014 | Data Loss: -3.8744
# Total Loss: 0.2382 | PDE Loss: -2.5496 | Boundary Loss: -5.0783 | Data Loss: -3.8774
# Total Loss: 0.2382 | PDE Loss: -2.5496 | Boundary Loss: -5.0776 | Data Loss: -3.8775
# Total Loss: 0.2382 | PDE Loss: -2.5495 | Boundary Loss: -5.0804 | Data Loss: -3.8777
# Total Loss: 0.2382 | PDE Loss: -2.5493 | Boundary Loss: -5.0814 | Data Loss: -3.8779
# Total Loss: 0.2382 | PDE Loss: -2.5482 | Boundary Loss: -5.0951 | Data Loss: -3.8801
# Total Loss: 0.2381 | PDE Loss: -2.5423 | Boundary Loss: -5.1501 | Data Loss: -3.8871
# Total Loss: 0.2381 | PDE Loss: -2.5423 | Boundary Loss: -5.1506 | Data Loss: -3.8871
# Total Loss: 0.2381 | PDE Loss: -2.5422 | Boundary Loss: -5.1506 | Data Loss: -3.8871
# Total Loss: 0.2381 | PDE Loss: -2.5420 | Boundary Loss: -5.1515 | Data Loss: -3.8871
# Total Loss: 0.2381 | PDE Loss: -2.5414 | Boundary Loss: -5.1529 | Data Loss: -3.8871
# Total Loss: 0.2380 | PDE Loss: -2.5370 | Boundary Loss: -5.1462 | Data Loss: -3.8840
# Total Loss: 0.2380 | PDE Loss: -2.5369 | Boundary Loss: -5.1460 | Data Loss: -3.8840
# Total Loss: 0.2380 | PDE Loss: -2.5369 | Boundary Loss: -5.1474 | Data Loss: -3.8839
# Total Loss: 0.2380 | PDE Loss: -2.5368 | Boundary Loss: -5.1475 | Data Loss: -3.8838
# Total Loss: 0.2380 | PDE Loss: -2.5367 | Boundary Loss: -5.1466 | Data Loss: -3.8836
# Total Loss: 0.2379 | PDE Loss: -2.5354 | Boundary Loss: -5.1527 | Data Loss: -3.8811
# Total Loss: 0.2377 | PDE Loss: -2.5274 | Boundary Loss: -5.1254 | Data Loss: -3.8561
# Total Loss: 0.2377 | PDE Loss: -2.5274 | Boundary Loss: -5.1255 | Data Loss: -3.8560
# Total Loss: 0.2377 | PDE Loss: -2.5274 | Boundary Loss: -5.1252 | Data Loss: -3.8559
# Total Loss: 0.2377 | PDE Loss: -2.5274 | Boundary Loss: -5.1250 | Data Loss: -3.8552
# Total Loss: 0.2377 | PDE Loss: -2.5266 | Boundary Loss: -5.1271 | Data Loss: -3.8475
# Total Loss: 0.2375 | PDE Loss: -2.5223 | Boundary Loss: -5.0760 | Data Loss: -3.7999
# Total Loss: 0.2375 | PDE Loss: -2.5223 | Boundary Loss: -5.0764 | Data Loss: -3.7997
# Total Loss: 0.2375 | PDE Loss: -2.5223 | Boundary Loss: -5.0770 | Data Loss: -3.7993
# Total Loss: 0.2375 | PDE Loss: -2.5223 | Boundary Loss: -5.0769 | Data Loss: -3.7990
# Total Loss: 0.2375 | PDE Loss: -2.5225 | Boundary Loss: -5.0818 | Data Loss: -3.7954
# Total Loss: 0.2375 | PDE Loss: -2.5228 | Boundary Loss: -5.0917 | Data Loss: -3.7834
# Total Loss: 0.2371 | PDE Loss: -2.5219 | Boundary Loss: -4.8543 | Data Loss: -3.6363
# Total Loss: 0.2371 | PDE Loss: -2.5220 | Boundary Loss: -4.8551 | Data Loss: -3.6362
# Total Loss: 0.2371 | PDE Loss: -2.5220 | Boundary Loss: -4.8556 | Data Loss: -3.6362
# Total Loss: 0.2371 | PDE Loss: -2.5223 | Boundary Loss: -4.8623 | Data Loss: -3.6358
# Total Loss: 0.2371 | PDE Loss: -2.5240 | Boundary Loss: -4.9028 | Data Loss: -3.6339
# Total Loss: 0.2369 | PDE Loss: -2.5336 | Boundary Loss: -5.1724 | Data Loss: -3.6207
# Total Loss: 0.2369 | PDE Loss: -2.5337 | Boundary Loss: -5.1724 | Data Loss: -3.6205
# Total Loss: 0.2369 | PDE Loss: -2.5345 | Boundary Loss: -5.1705 | Data Loss: -3.6195
# Total Loss: 0.2368 | PDE Loss: -2.5375 | Boundary Loss: -5.1571 | Data Loss: -3.6156
# Total Loss: 0.2362 | PDE Loss: -2.5692 | Boundary Loss: -4.6831 | Data Loss: -3.5725
# Total Loss: 0.2362 | PDE Loss: -2.5694 | Boundary Loss: -4.6827 | Data Loss: -3.5725
# Total Loss: 0.2362 | PDE Loss: -2.5704 | Boundary Loss: -4.6819 | Data Loss: -3.5726
# Total Loss: 0.2361 | PDE Loss: -2.5753 | Boundary Loss: -4.6754 | Data Loss: -3.5730
# Total Loss: 0.2357 | PDE Loss: -2.6011 | Boundary Loss: -4.5881 | Data Loss: -3.5752
# Total Loss: 0.2357 | PDE Loss: -2.6013 | Boundary Loss: -4.5894 | Data Loss: -3.5754
# Total Loss: 0.2357 | PDE Loss: -2.6016 | Boundary Loss: -4.5901 | Data Loss: -3.5755
# Total Loss: 0.2356 | PDE Loss: -2.6037 | Boundary Loss: -4.5986 | Data Loss: -3.5771
# Total Loss: 0.2355 | PDE Loss: -2.6140 | Boundary Loss: -4.6345 | Data Loss: -3.5842
# Total Loss: 0.2347 | PDE Loss: -2.6640 | Boundary Loss: -4.7228 | Data Loss: -3.6164
# Total Loss: 0.2347 | PDE Loss: -2.6641 | Boundary Loss: -4.7231 | Data Loss: -3.6165
# Total Loss: 0.2347 | PDE Loss: -2.6642 | Boundary Loss: -4.7240 | Data Loss: -3.6166
# Total Loss: 0.2347 | PDE Loss: -2.6643 | Boundary Loss: -4.7223 | Data Loss: -3.6167
# Total Loss: 0.2347 | PDE Loss: -2.6657 | Boundary Loss: -4.7233 | Data Loss: -3.6177
# Total Loss: 0.2346 | PDE Loss: -2.6699 | Boundary Loss: -4.7205 | Data Loss: -3.6206
# Total Loss: 0.2342 | PDE Loss: -2.6938 | Boundary Loss: -4.6582 | Data Loss: -3.6363
# Total Loss: 0.2342 | PDE Loss: -2.6940 | Boundary Loss: -4.6600 | Data Loss: -3.6365
# Total Loss: 0.2342 | PDE Loss: -2.6942 | Boundary Loss: -4.6612 | Data Loss: -3.6367
# Total Loss: 0.2342 | PDE Loss: -2.6957 | Boundary Loss: -4.6739 | Data Loss: -3.6384
# Total Loss: 0.2340 | PDE Loss: -2.7037 | Boundary Loss: -4.7465 | Data Loss: -3.6471
# Total Loss: 0.2331 | PDE Loss: -2.7535 | Boundary Loss: -5.0474 | Data Loss: -3.6760
# Total Loss: 0.2331 | PDE Loss: -2.7535 | Boundary Loss: -5.0452 | Data Loss: -3.6760
# Total Loss: 0.2331 | PDE Loss: -2.7538 | Boundary Loss: -5.0371 | Data Loss: -3.6760
# Total Loss: 0.2331 | PDE Loss: -2.7544 | Boundary Loss: -5.0157 | Data Loss: -3.6760
# Total Loss: 0.2331 | PDE Loss: -2.7563 | Boundary Loss: -4.9422 | Data Loss: -3.6759
# Total Loss: 0.2331 | PDE Loss: -2.7564 | Boundary Loss: -4.9418 | Data Loss: -3.6759
# Total Loss: 0.2330 | PDE Loss: -2.7567 | Boundary Loss: -4.9403 | Data Loss: -3.6761
# Total Loss: 0.2330 | PDE Loss: -2.7585 | Boundary Loss: -4.9284 | Data Loss: -3.6774
# Total Loss: 0.2328 | PDE Loss: -2.7702 | Boundary Loss: -4.8208 | Data Loss: -3.6837
# Total Loss: 0.2328 | PDE Loss: -2.7703 | Boundary Loss: -4.8198 | Data Loss: -3.6839
# Total Loss: 0.2328 | PDE Loss: -2.7704 | Boundary Loss: -4.8198 | Data Loss: -3.6840
# Total Loss: 0.2328 | PDE Loss: -2.7708 | Boundary Loss: -4.8158 | Data Loss: -3.6843
# Total Loss: 0.2327 | PDE Loss: -2.7735 | Boundary Loss: -4.7940 | Data Loss: -3.6866
# Total Loss: 0.2324 | PDE Loss: -2.7916 | Boundary Loss: -4.5988 | Data Loss: -3.7004
# Total Loss: 0.2324 | PDE Loss: -2.7918 | Boundary Loss: -4.5991 | Data Loss: -3.7005
# Total Loss: 0.2324 | PDE Loss: -2.7919 | Boundary Loss: -4.5983 | Data Loss: -3.7006
# Total Loss: 0.2324 | PDE Loss: -2.7930 | Boundary Loss: -4.5955 | Data Loss: -3.7018
# Total Loss: 0.2323 | PDE Loss: -2.7995 | Boundary Loss: -4.5754 | Data Loss: -3.7080
# Total Loss: 0.2316 | PDE Loss: -2.8758 | Boundary Loss: -4.0553 | Data Loss: -3.7410
# Total Loss: 0.2316 | PDE Loss: -2.8759 | Boundary Loss: -4.0555 | Data Loss: -3.7411
# Total Loss: 0.2316 | PDE Loss: -2.8761 | Boundary Loss: -4.0574 | Data Loss: -3.7414
# Total Loss: 0.2316 | PDE Loss: -2.8762 | Boundary Loss: -4.0582 | Data Loss: -3.7416
# Total Loss: 0.2316 | PDE Loss: -2.8780 | Boundary Loss: -4.0710 | Data Loss: -3.7442
# Total Loss: 0.2314 | PDE Loss: -2.8869 | Boundary Loss: -4.1451 | Data Loss: -3.7575
# Total Loss: 0.2314 | PDE Loss: -2.8870 | Boundary Loss: -4.1455 | Data Loss: -3.7577
# Total Loss: 0.2314 | PDE Loss: -2.8874 | Boundary Loss: -4.1470 | Data Loss: -3.7587
# Total Loss: 0.2313 | PDE Loss: -2.8894 | Boundary Loss: -4.1566 | Data Loss: -3.7640
# Total Loss: 0.2310 | PDE Loss: -2.8993 | Boundary Loss: -4.2055 | Data Loss: -3.7913
# Total Loss: 0.2310 | PDE Loss: -2.8994 | Boundary Loss: -4.2061 | Data Loss: -3.7915
# Total Loss: 0.2310 | PDE Loss: -2.8996 | Boundary Loss: -4.2101 | Data Loss: -3.7922
# Total Loss: 0.2310 | PDE Loss: -2.8999 | Boundary Loss: -4.2140 | Data Loss: -3.7931
# Total Loss: 0.2309 | PDE Loss: -2.9023 | Boundary Loss: -4.2525 | Data Loss: -3.8011
# Total Loss: 0.2302 | PDE Loss: -2.9160 | Boundary Loss: -4.5649 | Data Loss: -3.8432
# Total Loss: 0.2302 | PDE Loss: -2.9160 | Boundary Loss: -4.5641 | Data Loss: -3.8434
# Total Loss: 0.2302 | PDE Loss: -2.9162 | Boundary Loss: -4.5636 | Data Loss: -3.8441
# Total Loss: 0.2302 | PDE Loss: -2.9165 | Boundary Loss: -4.5619 | Data Loss: -3.8453
# Total Loss: 0.2301 | PDE Loss: -2.9185 | Boundary Loss: -4.5481 | Data Loss: -3.8543
# Total Loss: 0.2296 | PDE Loss: -2.9269 | Boundary Loss: -4.3682 | Data Loss: -3.8918
# Total Loss: 0.2296 | PDE Loss: -2.9269 | Boundary Loss: -4.3689 | Data Loss: -3.8919
# Total Loss: 0.2296 | PDE Loss: -2.9269 | Boundary Loss: -4.3714 | Data Loss: -3.8919
# Total Loss: 0.2295 | PDE Loss: -2.9268 | Boundary Loss: -4.3857 | Data Loss: -3.8923
# Total Loss: 0.2293 | PDE Loss: -2.9266 | Boundary Loss: -4.4562 | Data Loss: -3.8908
# Total Loss: 0.2293 | PDE Loss: -2.9267 | Boundary Loss: -4.4566 | Data Loss: -3.8908
# Total Loss: 0.2293 | PDE Loss: -2.9267 | Boundary Loss: -4.4566 | Data Loss: -3.8908
# Total Loss: 0.2293 | PDE Loss: -2.9269 | Boundary Loss: -4.4575 | Data Loss: -3.8907
# Total Loss: 0.2292 | PDE Loss: -2.9279 | Boundary Loss: -4.4603 | Data Loss: -3.8897
# Total Loss: 0.2289 | PDE Loss: -2.9341 | Boundary Loss: -4.4177 | Data Loss: -3.8800
# Total Loss: 0.2289 | PDE Loss: -2.9341 | Boundary Loss: -4.4184 | Data Loss: -3.8799
# Total Loss: 0.2289 | PDE Loss: -2.9341 | Boundary Loss: -4.4194 | Data Loss: -3.8799
# Total Loss: 0.2289 | PDE Loss: -2.9341 | Boundary Loss: -4.4198 | Data Loss: -3.8798
# Total Loss: 0.2289 | PDE Loss: -2.9337 | Boundary Loss: -4.4312 | Data Loss: -3.8785
# Total Loss: 0.2288 | PDE Loss: -2.9331 | Boundary Loss: -4.4545 | Data Loss: -3.8754
# Total Loss: 0.2285 | PDE Loss: -2.9283 | Boundary Loss: -4.6082 | Data Loss: -3.8479
# Total Loss: 0.2285 | PDE Loss: -2.9283 | Boundary Loss: -4.6085 | Data Loss: -3.8478
# Total Loss: 0.2285 | PDE Loss: -2.9284 | Boundary Loss: -4.6077 | Data Loss: -3.8477
# Total Loss: 0.2285 | PDE Loss: -2.9287 | Boundary Loss: -4.6022 | Data Loss: -3.8470
# Total Loss: 0.2284 | PDE Loss: -2.9307 | Boundary Loss: -4.5711 | Data Loss: -3.8431
# Total Loss: 0.2283 | PDE Loss: -2.9380 | Boundary Loss: -4.4253 | Data Loss: -3.8292
# Total Loss: 0.2283 | PDE Loss: -2.9380 | Boundary Loss: -4.4257 | Data Loss: -3.8291
# Total Loss: 0.2283 | PDE Loss: -2.9380 | Boundary Loss: -4.4275 | Data Loss: -3.8283
# Total Loss: 0.2282 | PDE Loss: -2.9381 | Boundary Loss: -4.4355 | Data Loss: -3.8243
# Total Loss: 0.2281 | PDE Loss: -2.9379 | Boundary Loss: -4.4678 | Data Loss: -3.8010
# Total Loss: 0.2281 | PDE Loss: -2.9379 | Boundary Loss: -4.4683 | Data Loss: -3.8009
# Total Loss: 0.2281 | PDE Loss: -2.9378 | Boundary Loss: -4.4684 | Data Loss: -3.8008
# Total Loss: 0.2280 | PDE Loss: -2.9378 | Boundary Loss: -4.4694 | Data Loss: -3.8000
# Total Loss: 0.2280 | PDE Loss: -2.9375 | Boundary Loss: -4.4729 | Data Loss: -3.7954
# Total Loss: 0.2278 | PDE Loss: -2.9343 | Boundary Loss: -4.4608 | Data Loss: -3.7662
# Total Loss: 0.2278 | PDE Loss: -2.9343 | Boundary Loss: -4.4615 | Data Loss: -3.7661
# Total Loss: 0.2278 | PDE Loss: -2.9343 | Boundary Loss: -4.4614 | Data Loss: -3.7661
# Total Loss: 0.2278 | PDE Loss: -2.9342 | Boundary Loss: -4.4639 | Data Loss: -3.7652
# Total Loss: 0.2278 | PDE Loss: -2.9341 | Boundary Loss: -4.4666 | Data Loss: -3.7640
# Total Loss: 0.2277 | PDE Loss: -2.9330 | Boundary Loss: -4.4899 | Data Loss: -3.7536
# Total Loss: 0.2274 | PDE Loss: -2.9193 | Boundary Loss: -4.5296 | Data Loss: -3.6809
# Total Loss: 0.2274 | PDE Loss: -2.9192 | Boundary Loss: -4.5294 | Data Loss: -3.6809
# Total Loss: 0.2274 | PDE Loss: -2.9192 | Boundary Loss: -4.5295 | Data Loss: -3.6809
# Total Loss: 0.2274 | PDE Loss: -2.9192 | Boundary Loss: -4.5295 | Data Loss: -3.6809
# Total Loss: 0.2274 | PDE Loss: -2.9192 | Boundary Loss: -4.5295 | Data Loss: -3.6809
# Total Loss: 0.2274 | PDE Loss: -2.9192 | Boundary Loss: -4.5295 | Data Loss: -3.6809
# Total Loss: 0.2274 | PDE Loss: -2.9192 | Boundary Loss: -4.5295 | Data Loss: -3.6809
# Total Loss: 0.2274 | PDE Loss: -2.9191 | Boundary Loss: -4.5303 | Data Loss: -3.6807
# Total Loss: 0.2274 | PDE Loss: -2.9190 | Boundary Loss: -4.5309 | Data Loss: -3.6805
# Total Loss: 0.2274 | PDE Loss: -2.9179 | Boundary Loss: -4.5402 | Data Loss: -3.6784
# Total Loss: 0.2274 | PDE Loss: -2.9150 | Boundary Loss: -4.5634 | Data Loss: -3.6731
# Total Loss: 0.2273 | PDE Loss: -2.9051 | Boundary Loss: -4.6327 | Data Loss: -3.6559
# Total Loss: 0.2273 | PDE Loss: -2.9050 | Boundary Loss: -4.6329 | Data Loss: -3.6558
# Total Loss: 0.2273 | PDE Loss: -2.9048 | Boundary Loss: -4.6324 | Data Loss: -3.6555
# Total Loss: 0.2273 | PDE Loss: -2.9047 | Boundary Loss: -4.6301 | Data Loss: -3.6553
# ...
# Total Loss: 0.2119 | PDE Loss: -2.5536 | Boundary Loss: -4.7731 | Data Loss: -3.7024
# Total Loss: 0.2118 | PDE Loss: -2.5539 | Boundary Loss: -4.7702 | Data Loss: -3.7031
# Total Loss: 0.2118 | PDE Loss: -2.5566 | Boundary Loss: -4.7473 | Data Loss: -3.7093
# Total Loss: 0.2118 | PDE Loss: -2.5567 | Boundary Loss: -4.7470 | Data Loss: -3.7093
# Total Loss: 0.2118 | PDE Loss: -2.5568 | Boundary Loss: -4.7464 | Data Loss: -3.7096
# Total Loss: 0.2118 | PDE Loss: -2.5577 | Boundary Loss: -4.7426 | Data Loss: -3.7111
# Total Loss: 0.2118 | PDE Loss: -2.5627 | Boundary Loss: -4.7142 | Data Loss: -3.7198
# Total Loss: 0.2118 | PDE Loss: -2.5628 | Boundary Loss: -4.7141 | Data Loss: -3.7199
# Total Loss: 0.2118 | PDE Loss: -2.5630 | Boundary Loss: -4.7136 | Data Loss: -3.7201
# Total Loss: 0.2118 | PDE Loss: -2.5637 | Boundary Loss: -4.7122 | Data Loss: -3.7212
# Total Loss: 0.2118 | PDE Loss: -2.5649 | Boundary Loss: -4.7092 | Data Loss: -3.7227
# Total Loss: 0.2117 | PDE Loss: -2.5685 | Boundary Loss: -4.6949 | Data Loss: -3.7278
# Total Loss: 0.2117 | PDE Loss: -2.5686 | Boundary Loss: -4.6950 | Data Loss: -3.7279
# Total Loss: 0.2117 | PDE Loss: -2.5686 | Boundary Loss: -4.6949 | Data Loss: -3.7279
# Total Loss: 0.2117 | PDE Loss: -2.5686 | Boundary Loss: -4.6949 | Data Loss: -3.7279
# Total Loss: 0.2117 | PDE Loss: -2.5686 | Boundary Loss: -4.6949 | Data Loss: -3.7279
# Total Loss: 0.2117 | PDE Loss: -2.5686 | Boundary Loss: -4.6949 | Data Loss: -3.7279
# Total Loss: 0.2117 | PDE Loss: -2.5686 | Boundary Loss: -4.6957 | Data Loss: -3.7280
# Total Loss: 0.2117 | PDE Loss: -2.5687 | Boundary Loss: -4.6955 | Data Loss: -3.7280
# Total Loss: 0.2117 | PDE Loss: -2.5687 | Boundary Loss: -4.6954 | Data Loss: -3.7280
# Total Loss: 0.2117 | PDE Loss: -2.5687 | Boundary Loss: -4.6955 | Data Loss: -3.7280
# Total Loss: 0.2117 | PDE Loss: -2.5687 | Boundary Loss: -4.6955 | Data Loss: -3.7280
# Total Loss: 0.2117 | PDE Loss: -2.5687 | Boundary Loss: -4.6952 | Data Loss: -3.7280
# Total Loss: 0.2117 | PDE Loss: -2.5691 | Boundary Loss: -4.6957 | Data Loss: -3.7284
# Total Loss: 0.2117 | PDE Loss: -2.5696 | Boundary Loss: -4.6968 | Data Loss: -3.7288
# Total Loss: 0.2117 | PDE Loss: -2.5736 | Boundary Loss: -4.6992 | Data Loss: -3.7327
# Total Loss: 0.2116 | PDE Loss: -2.5953 | Boundary Loss: -4.6460 | Data Loss: -3.7564
# Total Loss: 0.2116 | PDE Loss: -2.5953 | Boundary Loss: -4.6460 | Data Loss: -3.7564
# Total Loss: 0.2116 | PDE Loss: -2.5953 | Boundary Loss: -4.6461 | Data Loss: -3.7564
# Total Loss: 0.2116 | PDE Loss: -2.5953 | Boundary Loss: -4.6460 | Data Loss: -3.7564
# Total Loss: 0.2116 | PDE Loss: -2.5953 | Boundary Loss: -4.6461 | Data Loss: -3.7564
# Total Loss: 0.2116 | PDE Loss: -2.5953 | Boundary Loss: -4.6461 | Data Loss: -3.7564
# Total Loss: 0.2116 | PDE Loss: -2.5954 | Boundary Loss: -4.6461 | Data Loss: -3.7564
# Total Loss: 0.2116 | PDE Loss: -2.5958 | Boundary Loss: -4.6465 | Data Loss: -3.7566
# Total Loss: 0.2116 | PDE Loss: -2.5977 | Boundary Loss: -4.6509 | Data Loss: -3.7574
# Total Loss: 0.2116 | PDE Loss: -2.6013 | Boundary Loss: -4.6566 | Data Loss: -3.7590
# Total Loss: 0.2116 | PDE Loss: -2.6013 | Boundary Loss: -4.6561 | Data Loss: -3.7591
# Total Loss: 0.2116 | PDE Loss: -2.6013 | Boundary Loss: -4.6561 | Data Loss: -3.7591
# Total Loss: 0.2116 | PDE Loss: -2.6013 | Boundary Loss: -4.6561 | Data Loss: -3.7591
# Total Loss: 0.2116 | PDE Loss: -2.6013 | Boundary Loss: -4.6561 | Data Loss: -3.7591
# Total Loss: 0.2116 | PDE Loss: -2.6015 | Boundary Loss: -4.6577 | Data Loss: -3.7590
# Total Loss: 0.2116 | PDE Loss: -2.6016 | Boundary Loss: -4.6590 | Data Loss: -3.7590
# Total Loss: 0.2116 | PDE Loss: -2.6030 | Boundary Loss: -4.6706 | Data Loss: -3.7590
# Total Loss: 0.2116 | PDE Loss: -2.6064 | Boundary Loss: -4.6984 | Data Loss: -3.7588
# Total Loss: 0.2116 | PDE Loss: -2.6065 | Boundary Loss: -4.6986 | Data Loss: -3.7588
# Total Loss: 0.2116 | PDE Loss: -2.6067 | Boundary Loss: -4.7005 | Data Loss: -3.7589
# Total Loss: 0.2116 | PDE Loss: -2.6081 | Boundary Loss: -4.7095 | Data Loss: -3.7593
# Total Loss: 0.2115 | PDE Loss: -2.6104 | Boundary Loss: -4.7248 | Data Loss: -3.7599
# Total Loss: 0.2115 | PDE Loss: -2.6167 | Boundary Loss: -4.7642 | Data Loss: -3.7619
# Total Loss: 0.2115 | PDE Loss: -2.6168 | Boundary Loss: -4.7646 | Data Loss: -3.7619
# Total Loss: 0.2115 | PDE Loss: -2.6168 | Boundary Loss: -4.7650 | Data Loss: -3.7619
# Total Loss: 0.2115 | PDE Loss: -2.6168 | Boundary Loss: -4.7654 | Data Loss: -3.7619
# Total Loss: 0.2115 | PDE Loss: -2.6168 | Boundary Loss: -4.7649 | Data Loss: -3.7619
# Total Loss: 0.2115 | PDE Loss: -2.6168 | Boundary Loss: -4.7650 | Data Loss: -3.7619
# Total Loss: 0.2115 | PDE Loss: -2.6169 | Boundary Loss: -4.7648 | Data Loss: -3.7619
# Total Loss: 0.2115 | PDE Loss: -2.6172 | Boundary Loss: -4.7659 | Data Loss: -3.7621
# Total Loss: 0.2115 | PDE Loss: -2.6174 | Boundary Loss: -4.7668 | Data Loss: -3.7621
# Total Loss: 0.2115 | PDE Loss: -2.6202 | Boundary Loss: -4.7774 | Data Loss: -3.7632
# Total Loss: 0.2115 | PDE Loss: -2.6288 | Boundary Loss: -4.8022 | Data Loss: -3.7669
# Total Loss: 0.2115 | PDE Loss: -2.6289 | Boundary Loss: -4.8027 | Data Loss: -3.7670
# Total Loss: 0.2115 | PDE Loss: -2.6289 | Boundary Loss: -4.8031 | Data Loss: -3.7670
# Total Loss: 0.2115 | PDE Loss: -2.6289 | Boundary Loss: -4.8028 | Data Loss: -3.7670
# Total Loss: 0.2115 | PDE Loss: -2.6289 | Boundary Loss: -4.8031 | Data Loss: -3.7670
# Total Loss: 0.2115 | PDE Loss: -2.6289 | Boundary Loss: -4.8034 | Data Loss: -3.7670
# Total Loss: 0.2115 | PDE Loss: -2.6289 | Boundary Loss: -4.8034 | Data Loss: -3.7670
# Total Loss: 0.2115 | PDE Loss: -2.6290 | Boundary Loss: -4.8026 | Data Loss: -3.7670
# Total Loss: 0.2115 | PDE Loss: -2.6294 | Boundary Loss: -4.8027 | Data Loss: -3.7673
# Total Loss: 0.2115 | PDE Loss: -2.6300 | Boundary Loss: -4.8035 | Data Loss: -3.7677
# Total Loss: 0.2115 | PDE Loss: -2.6305 | Boundary Loss: -4.8025 | Data Loss: -3.7680
# Total Loss: 0.2114 | PDE Loss: -2.6377 | Boundary Loss: -4.7961 | Data Loss: -3.7730
# Total Loss: 0.2114 | PDE Loss: -2.6378 | Boundary Loss: -4.7960 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6378 | Boundary Loss: -4.7959 | Data Loss: -3.7730
# Total Loss: 0.2114 | PDE Loss: -2.6378 | Boundary Loss: -4.7959 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6378 | Boundary Loss: -4.7959 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6379 | Boundary Loss: -4.7968 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6379 | Boundary Loss: -4.7966 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6379 | Boundary Loss: -4.7969 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6379 | Boundary Loss: -4.7969 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6380 | Boundary Loss: -4.7964 | Data Loss: -3.7731
# Total Loss: 0.2114 | PDE Loss: -2.6380 | Boundary Loss: -4.7964 | Data Loss: -3.7732
# Total Loss: 0.2114 | PDE Loss: -2.6380 | Boundary Loss: -4.7964 | Data Loss: -3.7732
# Total Loss: 0.2114 | PDE Loss: -2.6381 | Boundary Loss: -4.7971 | Data Loss: -3.7732
# Total Loss: 0.2114 | PDE Loss: -2.6383 | Boundary Loss: -4.7980 | Data Loss: -3.7732
# Total Loss: 0.2114 | PDE Loss: -2.6384 | Boundary Loss: -4.7977 | Data Loss: -3.7733
# Total Loss: 0.2114 | PDE Loss: -2.6404 | Boundary Loss: -4.8078 | Data Loss: -3.7737
# Total Loss: 0.2114 | PDE Loss: -2.6432 | Boundary Loss: -4.8184 | Data Loss: -3.7743
# Total Loss: 0.2113 | PDE Loss: -2.6654 | Boundary Loss: -4.8628 | Data Loss: -3.7817
# Total Loss: 0.2113 | PDE Loss: -2.6654 | Boundary Loss: -4.8632 | Data Loss: -3.7818
# Total Loss: 0.2113 | PDE Loss: -2.6655 | Boundary Loss: -4.8629 | Data Loss: -3.7818
# Total Loss: 0.2113 | PDE Loss: -2.6655 | Boundary Loss: -4.8632 | Data Loss: -3.7818
# Total Loss: 0.2113 | PDE Loss: -2.6655 | Boundary Loss: -4.8632 | Data Loss: -3.7818
# Total Loss: 0.2113 | PDE Loss: -2.6655 | Boundary Loss: -4.8632 | Data Loss: -3.7818
# Total Loss: 0.2113 | PDE Loss: -2.6659 | Boundary Loss: -4.8633 | Data Loss: -3.7820
# Total Loss: 0.2113 | PDE Loss: -2.6663 | Boundary Loss: -4.8630 | Data Loss: -3.7822
# Total Loss: 0.2113 | PDE Loss: -2.6698 | Boundary Loss: -4.8602 | Data Loss: -3.7842
# Total Loss: 0.2112 | PDE Loss: -2.6803 | Boundary Loss: -4.8326 | Data Loss: -3.7906
# Total Loss: 0.2112 | PDE Loss: -2.6804 | Boundary Loss: -4.8335 | Data Loss: -3.7907
# Total Loss: 0.2112 | PDE Loss: -2.6804 | Boundary Loss: -4.8332 | Data Loss: -3.7907
# Total Loss: 0.2112 | PDE Loss: -2.6804 | Boundary Loss: -4.8334 | Data Loss: -3.7907
# Total Loss: 0.2112 | PDE Loss: -2.6804 | Boundary Loss: -4.8332 | Data Loss: -3.7907
# Total Loss: 0.2112 | PDE Loss: -2.6804 | Boundary Loss: -4.8332 | Data Loss: -3.7907
# Total Loss: 0.2112 | PDE Loss: -2.6805 | Boundary Loss: -4.8326 | Data Loss: -3.7907
# Total Loss: 0.2112 | PDE Loss: -2.6809 | Boundary Loss: -4.8326 | Data Loss: -3.7909
# Total Loss: 0.2112 | PDE Loss: -2.6812 | Boundary Loss: -4.8315 | Data Loss: -3.7911
# Total Loss: 0.2112 | PDE Loss: -2.6851 | Boundary Loss: -4.8232 | Data Loss: -3.7931
# Total Loss: 0.2111 | PDE Loss: -2.6960 | Boundary Loss: -4.7758 | Data Loss: -3.7996
# Total Loss: 0.2111 | PDE Loss: -2.6960 | Boundary Loss: -4.7752 | Data Loss: -3.7996
# Total Loss: 0.2111 | PDE Loss: -2.6963 | Boundary Loss: -4.7757 | Data Loss: -3.7998
# Total Loss: 0.2111 | PDE Loss: -2.6965 | Boundary Loss: -4.7747 | Data Loss: -3.7998
# Total Loss: 0.2111 | PDE Loss: -2.6986 | Boundary Loss: -4.7729 | Data Loss: -3.8005
# Total Loss: 0.2111 | PDE Loss: -2.7025 | Boundary Loss: -4.7659 | Data Loss: -3.8020
# Total Loss: 0.2111 | PDE Loss: -2.7026 | Boundary Loss: -4.7654 | Data Loss: -3.8021
# Total Loss: 0.2111 | PDE Loss: -2.7029 | Boundary Loss: -4.7655 | Data Loss: -3.8021
# Total Loss: 0.2111 | PDE Loss: -2.7035 | Boundary Loss: -4.7667 | Data Loss: -3.8022
# Total Loss: 0.2111 | PDE Loss: -2.7075 | Boundary Loss: -4.7690 | Data Loss: -3.8031
# Total Loss: 0.2110 | PDE Loss: -2.7277 | Boundary Loss: -4.7148 | Data Loss: -3.8101
# Total Loss: 0.2110 | PDE Loss: -2.7278 | Boundary Loss: -4.7148 | Data Loss: -3.8101
# Total Loss: 0.2110 | PDE Loss: -2.7279 | Boundary Loss: -4.7156 | Data Loss: -3.8101
# Total Loss: 0.2110 | PDE Loss: -2.7283 | Boundary Loss: -4.7157 | Data Loss: -3.8101
# Total Loss: 0.2110 | PDE Loss: -2.7302 | Boundary Loss: -4.7203 | Data Loss: -3.8100
# Total Loss: 0.2109 | PDE Loss: -2.7334 | Boundary Loss: -4.7239 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7335 | Boundary Loss: -4.7245 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7335 | Boundary Loss: -4.7242 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7335 | Boundary Loss: -4.7242 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7335 | Boundary Loss: -4.7242 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7335 | Boundary Loss: -4.7242 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7335 | Boundary Loss: -4.7242 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7337 | Boundary Loss: -4.7253 | Data Loss: -3.8099
# Total Loss: 0.2109 | PDE Loss: -2.7338 | Boundary Loss: -4.7251 | Data Loss: -3.8098
# Total Loss: 0.2109 | PDE Loss: -2.7354 | Boundary Loss: -4.7311 | Data Loss: -3.8096
# Total Loss: 0.2109 | PDE Loss: -2.7399 | Boundary Loss: -4.7428 | Data Loss: -3.8089
# Total Loss: 0.2109 | PDE Loss: -2.7399 | Boundary Loss: -4.7429 | Data Loss: -3.8089
# Total Loss: 0.2109 | PDE Loss: -2.7399 | Boundary Loss: -4.7431 | Data Loss: -3.8089
# Total Loss: 0.2109 | PDE Loss: -2.7402 | Boundary Loss: -4.7454 | Data Loss: -3.8088
# Total Loss: 0.2109 | PDE Loss: -2.7419 | Boundary Loss: -4.7584 | Data Loss: -3.8080
# Total Loss: 0.2108 | PDE Loss: -2.7523 | Boundary Loss: -4.8175 | Data Loss: -3.8023
# Total Loss: 0.2108 | PDE Loss: -2.7524 | Boundary Loss: -4.8172 | Data Loss: -3.8023
# Total Loss: 0.2108 | PDE Loss: -2.7525 | Boundary Loss: -4.8175 | Data Loss: -3.8023
# Total Loss: 0.2108 | PDE Loss: -2.7527 | Boundary Loss: -4.8181 | Data Loss: -3.8022
# Total Loss: 0.2108 | PDE Loss: -2.7529 | Boundary Loss: -4.8178 | Data Loss: -3.8021
# Total Loss: 0.2108 | PDE Loss: -2.7555 | Boundary Loss: -4.8159 | Data Loss: -3.8013
# Total Loss: 0.2107 | PDE Loss: -2.7675 | Boundary Loss: -4.7271 | Data Loss: -3.7975
# Total Loss: 0.2107 | PDE Loss: -2.7675 | Boundary Loss: -4.7268 | Data Loss: -3.7974
# Total Loss: 0.2107 | PDE Loss: -2.7675 | Boundary Loss: -4.7265 | Data Loss: -3.7975
# Total Loss: 0.2107 | PDE Loss: -2.7675 | Boundary Loss: -4.7268 | Data Loss: -3.7974
# Total Loss: 0.2107 | PDE Loss: -2.7675 | Boundary Loss: -4.7268 | Data Loss: -3.7974
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7285 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7293 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7295 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7293 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7293 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7287 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7290 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7287 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7290 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7287 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7290 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7287 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7290 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7287 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7290 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7287 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7290 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7287 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7290 | Data Loss: -3.7973
# Total Loss: 0.2107 | PDE Loss: -2.7676 | Boundary Loss: -4.7298 | Data Loss: -3.7973
# Final Loss: 0.210684
# Relative L2 Error: 0.109095%
